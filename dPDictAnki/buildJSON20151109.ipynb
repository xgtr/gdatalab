# %%
# feel a little weird, but it's much better than ugly 'dir > a text'

# read images folders to create image files lists

import codecs
import os
from os import listdir
from os.path import isfile, join

n=3 # n folders and outfiles

# add u will read unicode name like piñata.gif correctly
folder = [u"E:\\dictIllustration\\mwl-358(266-92)\\mwl-single-266\\",
    u"E:\\dictIllustration\\mwl-358(266-92)\\mwl-grpbw-92\\",
    u"E:\\dictIllustration\\mwl-grpcolor-16\\"]

outfile = ["E:\\1Now\\taglist\\mwlimgSingle.txt", # black-and-white single images
     "E:\\1Now\\taglist\\mwlimgGrpbw.txt", # black-and-white group images
     "E:\\1Now\\taglist\\mwlimgGrpcol.txt"] # color pages

cntx = [0, 0, 0] # how many files in each folder

for i in range(0,n):
    with codecs.open(outfile[i], 'w', 'utf-8') as f:
        for finfolder in os.listdir(folder[i]):
            if isfile(join(folder[i], finfolder)):
                f.write(finfolder+'\n')
                cntx[i] += 1
        f.close()
for k in cntx:
    print k

# for i in os.listdir(x):
#     if isfile(join(x, i)):
#         print i, '...', join(x, i)
#         cnt1 += 1
#     else:
#         print 'not a file: ', i
#         cnt2 += 1
# print 'number of files: ', cnt1, 'number of non-files: ', cnt2
# Out:
# 266
# 92
# 16

# %%
# create empty group images list files
import codecs

a = "E:\\1Now\\taglist\\mwlimgGrpbw.txt" # 90 empty files
# a = "E:\\1Now\\taglist\\mwlimgGrpcol.txt" # 16 empty files

outfolder = "E:\\1Now\\taglist\\mwlimglist\\"
with codecs.open(a, 'r', 'utf-8') as f:
    names = f.read().splitlines()
    f.close()
cnt = 0
for name in names:
    open(outfolder + name + '.txt', 'w')
    cnt += 1
print cnt
# Out:
# 92

# %%
a = os.listdir("E:\\1Now\\taglist\\mwlimglist\\")
print len(a)
print a
# Out:
# 106
# ['airplane.gif.txt', 'alligator.gif.txt', 'ape.gif.txt', 'bag.gif.txt', 'baking.gif.txt', 'ball.gif.txt', 'bat.gif.txt', 'bathroom.gif.txt', 'bear.gif.txt', 'beard.gif.txt', 'bed.gif.txt', 'bicycle.gif.txt', 'bird.gif.txt', 'birds c9.jpg.txt', 'boat.gif.txt', 'brass instrument.gif.txt', 'camera.gif.txt', 'camping.gif.txt', 'carpentry.gif.txt', 'car_rev.gif.txt', 'car_types.gif.txt', 'cat.gif.txt', 'chess.gif.txt', 'clothing c13.jpg.txt', 'clothing c14.jpg.txt', 'clothing c15.jpg.txt', 'clothing c16.jpg.txt', 'colors c1.jpg.txt', 'colors c2.jpg.txt', 'colors c3.jpg.txt', 'computer.gif.txt', 'construction.gif.txt', 'deer.gif.txt', 'dog.gif.txt', 'dolphin.gif.txt', 'door.gif.txt', 'engine.gif.txt', 'eye.gif.txt', 'face.gif.txt', 'family.gif.txt', 'fan.gif.txt', 'fish and shellfish c8.jpg.txt', 'fishing.gif.txt', 'flower.gif.txt', 'font.gif.txt', 'foot.gif.txt', 'frog.gif.txt', 'fruits c5.jpg.txt', 'gardening.gif.txt', 'gems and jewelry c11.jpg.txt', 'geometry.gif.txt', 'glove.gif.txt', 'grooming.gif.txt', 'gun.gif.txt', 'gym.gif.txt', 'hair.gif.txt', 'hand.gif.txt', 'hat.gif.txt', 'hook.gif.txt', 'horse.gif.txt', 'hospital.gif.txt', 'house.gif.txt', 'human.gif.txt', 'insects and arachnids c10.jpg.txt', 'keyboard instruments.gif.txt', 'kitchen.gif.txt', 'knob.gif.txt', 'landscapes c7.jpg.txt', 'lighting.gif.txt', 'living room.gif.txt', 'llama.gif.txt', 'mail.gif.txt', 'motorcycle.gif.txt', 'mouth.gif.txt', 'nuts.gif.txt', 'office.gif.txt', 'orchestra.gif.txt', 'pasta.gif.txt', 'patterns c12.jpg.txt', 'percussion.gif.txt', 'place setting.gif.txt', 'plants c6.jpg.txt', 'playground.gif.txt', 'playing card.gif.txt', 'plow.gif.txt', 'plumbing.gif.txt', 'position.gif.txt', 'racket.gif.txt', 'rodent.gif.txt', 'scuba.gif.txt', 'sewing.gif.txt', 'ship.gif.txt', 'shoe.gif.txt', 'skate.gif.txt', 'ski.gif.txt', 'street.gif.txt', 'stringed instrument.gif.txt', 'telephone.gif.txt', 'theater.gif.txt', 'truck.gif.txt', 'vegetables c4.jpg.txt', 'windmill.gif.txt', 'window.gif.txt', 'wolf.gif.txt', 'woodwind.gif.txt', 'zodiac.gif.txt']

# %%
ab = set()
ab.add(1)
ab.add(2)
ab.add(2)
print ab, list(ab)
# Out:
# set([1, 2]) [1, 2]

# %%
# Extract data from 39195 raw files, transfer them to json, then load them into mongodb
#buildJSON20151109

from bs4 import BeautifulSoup
import json
import re
import os
from os import listdir
from os.path import isfile, join
import shutil
import codecs

import pymongo
from pymongo import MongoClient

#connect to MongoDB
client = MongoClient('localhost', 27017)
db = client.dpdb  # database: dpdb


#mypath = os.getcwd() + "\\rawfile"
testflag = 0 # if it is a test: 1-yes, 0-no

if testflag == 1:
    mypath = "E:\\dictrawfile-test\\"
    geweiDict = db.geweiDictTest
elif testflag == 0:
    mypath = "E:\\dictrawfile-39195\\"
    geweiDict = db.geweiDict201511 # collection (table): geweiDict201511
print mypath


def a_has_id(tag):
    return tag.has_attr('id')

def a_has_href(tag):
    return tag.has_attr('href')

tlpath = 'E:\\1Now\\taglist\\'

# 2939 basic words
bws = []
with codecs.open(tlpath + '2939bw.txt', 'r', 'utf-8') as f:
    bws = f.read().splitlines()
    f.close()


tfiles = ['wordRoot.txt', 'prefix.txt', 'suffix.txt']
topics = []
for tfile in tfiles:
    topic = {}
    with codecs.open('E:\\1Now\\taglist\\' + tfile, 'r', 'utf-8') as f:
        twords = f.read().splitlines()
        f.close()
    topic['words'] = twords
    topic['topic'] = tfile.split('.')[0]
    topics.append(topic)

    
# homographs
with codecs.open(tlpath + 'homog.txt', 'r', 'utf-8') as f:
    homogs = f.read().splitlines()
    f.close()
    
    
# imgages in mwaled
# 266 gif (single word images)
with codecs.open(tlpath + 'mwlimgSingle.txt', 'r', 'utf-8') as f:
    imgSingles = f.read().splitlines()
    f.close()

# 16 jpg (color pages)
# 92 gif (black-and-white group words images)
imgLists = os.listdir(tlpath + "mwlimgGrpwl\\")
imgGrps = []
for imgList in imgLists:
    imgGrp = {}
    with codecs.open(tlpath + "mwlimgGrpwl\\" + imgList, 'r', 'utf-8') as f:
        twords = f.read().splitlines()
        f.close()
    if twords:
        #print 'img group file "', imgList, '": ', twords
        imgGrp['words'] = twords
        imgGrp['img'] = imgList.split('.')[0] + '.' + imgList.split('.')[1]
        imgGrps.append(imgGrp)
    
    
labels = ('US', 'chiefly US', 'Brit', 'chiefly Brit', 'slang', 'offensive', 'obscene', 'impolite', 
          'informal', 'formal', 'literary', 'old-fashioned', 'humorous', 'technical', 
          'disapproving', 'approving', 'medical', 'law', 'baseball', 'mathematics', 'sports', 
          'grammar', 'trademark', 'old-fashioned')

#map IPA image symbols to my ASCII IPA symbols
ipa_to_alpha = {
    '22089': 'Z', #ZH -> Z
    '22212': 'Z', #ZH -> Z
    '22369': 'Z', #ZH -> Z
    '22077': 'z',
    '22200': 'y',
    '22047': 'w',
    '22005': 'v',
    '22218': 'u-Y',
    '22167': 'u-B',
    '22170': 'u-b',
    '22203': 'u-b',
    '22137': 'u-A',
    '22140': 'u-a',
    '22254': 'u-2',
    '22152': 'u-1',
    '22242': 'u-1',
    '22263': 'u-1',
    '22294': 'u-1',
    '22312': 'u-1',
    '22339': 'u-_',
    '22185': 'u-^',
    '22309': 'u-#',
    '22321': 'u-#',
    '22029': 'U', # u -> U
    '22074': 'u',
    '22342': 'U', # u -> U
    '22101': 'th', # TH -> th
    '22206': 'th', # TH -> th
    '22366': 'th', # TH -> th
    '22038': 't',
    '22044': 'S', # SH -> S
    '22209': 'S', # SH -> S
    '22363': 'S', # SH -> S
    '22014': 's',
    '22050': 'r',
    '22092': 'p',
    '22281': 'p',
    '22026': 'o',
    '22068': 'N', # NG -> N
    '22360': 'N', # NG -> N
    '21981': 'n',
    '22080': 'n-', # n -> n-
    '22357': 'n-', # n -> n-
    '22035': 'm',
    '22227': 'm',
    '22023': 'l',
    '22053': 'l-', # l -> l-
    '22354': 'l-', # l -> l-
    '22008': 'k',
    '22071': 'dZ', # JH -> dZ
    '22351': 'dZ', # JH -> dZ
    '22062': 'j',
    '21966': '!', # i -> !
    '22032': 'i',
    '22333': '!', # i -> !
    '22065': 'h',
    '22110': 'h',
    '22086': 'g',
    '22083': 'f',
    '21996': '~', # ER -> ~
    '22266': '~', # ER -> ~
    '22330': '~', # ER -> ~
    '21963': 'e',
    '22059': 'E', # e -> E
    '22269': 'E', # e -> E
    '22345': 'E', # e -> E
    '22131': 'TH', # DH -> TH
    '22116': 'dd', # no change but what 'dd' means?
    '21999': 'd',
    '22104': 'tS', # CH -> tS
    '22348': 'tS', # CH -> tS
    '22119': 'b-a',
    '22128': 'b-a',
    '22011': 'b',    
    '22056': '^', # AH -> ^
    '22327': '^', # AH -> ^
    '21975': '.', # AH -> .
    '22272': '.', # AH -> .
    '22324': '.', # AH -> .  
    '21984': '@', # AE -> @
    '21990': 'A', # a -> A
    '22020': 'a',
    '22257': 'A', # a -> A
    '22336': 'A', # a -> A
    '22041': 'u-~', # ~ -> u-~
    '22002': ',', # ` -> , secondary stress
    '21993': ':', # _ -> :
    '22260': ':', # _ -> :
    '21960': "'", # ^ -> ' primary stress
    '22149': ';',
    '21957': '/',
    '21978': '', # , -> null
    '21969': '#',
    '21972': '#',
    '21987': '#',
    '22017': '#',
    '22095': '#',
    '22098': '#',
    '22107': '#',
    '22113': '#',
    '22122': '#',
    '22125': '#',
    '22134': '#',
    '22143': '#',
    '22146': '#',
    '22155': '#',
    '22158': '#',
    '22161': '#',
    '22164': '#',
    '22173': '#',
    '22176': '#',
    '22179': '#',
    '22182': '#',
    '22188': '#',
    '22191': '#',
    '22194': '#',
    '22197': '#',
    '22215': '#',
    '22221': '#',
    '22224': '#',
    '22230': '#',
    '22233': '#',
    '22236': '#',
    '22239': '#',
    '22245': '#',
    '22248': '#',
    '22251': '#',
    '22275': '#',
    '22278': '#',
    '22284': '#',
    '22287': '#',
    '22291': '#',
    '22297': '#',
    '22300': '#',
    '22303': '#',
    '22306': '#',
    '22315': '#',
    '22318': '#',
    '22372': '#'
}



onlyfiles = [ f for f in os.listdir(mypath) if isfile(join(mypath,f)) ]

cnt = 0  #total words
cnt_f = 0 #number of foreign words (French, Spanish)
cnt_d = 0 #number of words beginning with a dash
cnt_sq = 0 #number of words beginning with a single quote

kk = 0
for fname in onlyfiles:
    jsonBody = {}
    
    if testflag == 0: fj = codecs.open('E:\\dictjson\\' + fname + '.json', 'w', 'utf-8')
    #print fj
    
    with open(mypath + fname, 'r') as fentry:    
    #with codecs.open('E:\\dictrawfile-39195\\' + fname, 'r', 'utf-8') as fentry: #don't work somehow
        raw_doc = fentry.read()
        fentry.close()
    #fentry = open('declare.axb8472', 'r')
    #hw_doc = fentry.read()
        
    
    #get IPA symbols
    #first find the pair of slashes used to mark the beginning and end of a pronunciation
    #image21955.gif, image21956.gif, image21957.gif -- images of a slash '/'
    patt = '<img hspace="0" align="middle" losrc="Images\/image21955\.gif" src="Images\/image21956\.gif" hisrc="Images\/image21957\.gif"\/>'
    pattern = patt + '(.*?)' + patt
    #print pattern
    ipa = re.compile(pattern, re.DOTALL)

    flag_brit = 0 #suppose there is no British pronunciation
    my_pronun = []
    for sounds in ipa.findall(raw_doc):
        i = 0
        for sound in sounds.split('<i>Brit</i>'):
            i += 1
            ipa_soup = BeautifulSoup(sound)
            if i == 1: cmu = ''
            elif i == 2: #'Brit'
                flag_brit = 1 #there is British pronunciation
                break #skip British pronunciation
            for symbol in ipa_soup.find_all('img'):
                key = symbol['hisrc'][12:-4]
                if key in ipa_to_alpha: cmu += ipa_to_alpha[key]
                else: cmu += key
            #print cmu
            #print "---\n"   
            my_pronun.append(cmu)
    #print my_pronun
    if my_pronun: jsonBody['prn'] = my_pronun
    if flag_brit == 1: jsonBody['prn_brit'] = 'y'
        
    
    #after getting IPA, remove all image tags    
    hw_doc = re.sub(r"(<img[^>]*\/>)", "", raw_doc)
    #remove Unicode 'middle dot' u+00B7
    hw_doc = re.sub(u"\u00B7", "", hw_doc)
    #print hw_doc
    #continue
    
    #fentry.close() # move up

    soup = BeautifulSoup(hw_doc)
    
    #get headword
    headword = soup.find('idx:orth')
    #if headword[0] == "'": headword = "\\" + headword
    if headword: 
        hw = headword['value']
        #jsonBody['hw'] = headword['value']
        jsonBody['hw'] = hw
        kk += 1
        print kk, '---', jsonBody
    else:
        print fname, ": no headword"
        break
        
    
    #check if it is in 3,000 basic English words by 'u' (not accurate when there's a usage section)    
    basic_word = soup.find('u')
    bwflag = 0
    if basic_word and hw in bws:
        bwflag = 1
        #jsonBody['bw'] = 1    
    #print jsonBody
    

    #special words
    frflag = 0
    dashflag = 0
    squote = 0 
    if fname[0] == '.':
        cnt_f += 1
        frflag = 1
        #jsonBody["fr"] = "y" #is it a foreign word? yes
    elif fname[0] == '-':
        cnt_d += 1
        dashflag = 1
        #jsonBody["dash"] = "y" # begin with a dash
    elif fname[0] == "'":
        cnt_sq += 1
        squote = 1
        #jsonBody["sq"] = "y" #begin with a single quote '
    
    
    #get inflection
    infl = []
    for it in soup.find_all('idx:iform'):
        infl.append(it['value'])
        #print infl
    if infl: jsonBody['infl'] = infl

    #get id
    aid = soup.find(a_has_id)
    #print type(aid)
    if aid: jsonBody['id'] = aid['id']

    #get part of speech
    #<i><font color="#999999">noun</font></i>
    pos = soup.find(color="#999999")
    if pos: jsonBody['pos'] = pos.get_text()

        
    # if headword in homograph list, generate "homog" key and value    
    homogflag = 0
    if hw in homogs:
        print 'is a homograph'
        homogflag = 1
        jsonBody['homog'] = headword['value'] + " " + pos.get_text() # not to append suffix, may wav or mp3
 
    # if head word is related to images
    hwimg = []
    hwimgtag = set()
    for imgSig in imgSingles:
        if hw == imgSig.split('.')[0]:
            hwimg.append(imgSig)
            hwimgtag.add('imgmwl')
            # print hw, ' has a single image: ', imgSig
    for imgGrp in imgGrps:
        if hw in imgGrp['words']:
            hwimg.append(imgGrp['img'])
            hwimgtag.add('imgmwlG')          
            # print hw, ' has a group image: ', imgGrp['img']
    if hwimg:
        jsonBody['img'] = hwimg
        
        
    #get labels
    label = []
    label = soup.find_all(text=labels)
    #some labels are not captured in tags, so use regex to get them
    if soup.find(text=re.compile("figuratively")): label.append("figuratively")
    if soup.find(text=re.compile("informal")): label.append("informal")
    #no 'see color picture' in mobi file
    #if soup.find_all(text=re.compile("see color picture")): label.append("color picture")
    if label: jsonBody['label'] = label

    #get common phrases
    cplist = []
    for item in soup.find_all('span'):
        if item.parent.name == 'font': cplist.append(item.get_text())
    if cplist: jsonBody['cp'] = cplist

    #get all example sentences
    examples = []
    for it in soup.find_all(color="#002984"):
        examples.append(it.get_text())
    if examples:
        jsonBody['alles'] = examples        

        totales = len(examples)        

        if totales >= 100: nes = "100+"
        elif totales >= 50: nes = "50-99"
        elif totales >= 10: nes = "10-49"
        elif totales >=  3: nes = "3-9"
        elif totales >=  2: nes = "2"
        elif totales >=  1: nes = "1"
    else: nes = "0"
        
        
    #get all idioms & phrasal verbs, including common phrases
    idpvs = []
    #get sub head words
    subhw = []
    for item in soup.find_all('span'):
        #print item.parent.name, "---", item.get_text()
        if item.parent.name != 'idx:entry':
            if ' ' in item.get_text(): idpvs.append(item.get_text())
            else: subhw.append(item.get_text())
                
#  if subhw == hw, that means that subhw may have different part of speech, so keep it though both are same.                
#             elif item.get_text()[0] == hw[0]: 
#                 # check if the first letters of hw and subhw are same, good for revolt, but 
#  not good for 334 words like 20/20, twenty-twenty, impressionism and Impressionism
#                 subhw.append(item.get_text())
    if idpvs: jsonBody['idpvs'] = idpvs
    if subhw: jsonBody['subhw'] = subhw
                

    #check if head word or sub head words are in some topic word lists
    tag = []
    #tag.append('mwl')
    tag.append('es' + nes)    
    for topic in topics:
        if hw in topic['words']: tag.append(topic['topic'])
    if homogflag == 1: tag.append('homog')
    if bwflag == 1: tag.append('bw')
    if frflag == 1: tag.append('fr')
    if dashflag == 1: tag.append('dash')
    if squote == 1: tag.append('squote')
    if hwimgtag:
        #print 'in hwimgtag'
        tag += list(hwimgtag)
            
# only check word in hw, don't check in subhw
# will use mwaled77 to get a word's head word which is used to check what tags are.
#         elif subhw:
#             for csubhw in subhw:
#                 if csubhw in topic['words']: tag.append(topic['topic'])
    if tag: jsonBody['tag'] = tag
        
                
    #get cross references
    cr = {}
    for link in soup.find_all(a_has_href):
        if link: cr[link.get('href').replace('#','')] = link.get_text().strip()
    if cr: jsonBody['cr'] = cr

        
    #construct definitions & examples
    sublist = []
    i = 1 #cross reference counter
    
    # remove j that is not necessary
    #j = 1 #idioms & phrasal verbs counter 

    for it in soup.find_all('blockquote'):
        #print it.parent.parent.name, ">>", it.parent.name, "---", it, "\n"
        if(it.parent.name=='idx:entry'):
            examp = []
            defi = it.get_text()
            if defi==" ": continue
            for e in it.find_all(color="#002984"):
                examp.append(e.get_text())
                defi = defi.replace(e.get_text(),"")
            #print defi
            #print examp

            subentry = {}
            # def is a key word of Python
            subentry['defi'] = defi
            subentry['es'] = examp
            #print subentry
            #print sublist                

            if subentry: sublist.append(subentry)
        
        #idioms & phrasal verbs
        if(it.parent.name=='div' and it.parent.parent.name!='blockquote'):
            subentry = {}
            
            #just use 'idpv' as key
            subentry['idpv'] = it.get_text()
            #subentry['idpv'+str(j)] = it.get_text()
            #j += 1
 
            #print subentry
            if subentry: sublist.append(subentry)

            
    if sublist: jsonBody['sublist'] = sublist
    if jsonBody:
        #print jsonBody
        cnt += 1
        
        #dump json into a file
        if testflag == 0: json.dump(jsonBody, fj, indent=4, sort_keys=True)
        
        # insert into MongoDB database
        doc_id = geweiDict.insert(jsonBody)
        #print doc_id 
        if testflag == 0: shutil.move(mypath + fname, "E:\\dictprocessed\\"+fname)
    if testflag == 0: fj.close()

print 'total words: ', cnt, ', French words: ', cnt_f, ", begin with a dash:", cnt_d, ", begin with a ': ", cnt_sq
# Out:
# E:\dictrawfile-39195\
# 1 --- {'prn': ["'kA:zk.z"], 'hw': "'cause"}
# 2 --- {'prn': ['.dtd;d'], 'hw': "'d"}
# 3 --- {'prn': ['.m'], 'hw': "'em"}
# 4 --- {'hw': "'ll"}
# 5 --- {'prn': ['.nn-'], 'hw': "'n'"}
# 6 --- {'prn': ["'ni:th"], 'hw': "'neath"}
# 7 --- {'prn': ['sptkfth;.zszSZtSdZ;z'], 'hw': "'s"}
# 8 --- {'hw': "'til"}
# 9 --- {'prn': ["'t!zt.z"], 'hw': "'tis"}
# 10 --- {'prn': ["'tw^z"], 'hw': "'twas"}
# 11 --- {'prn': ['v.v'], 'hw': "'ve"}
# 12 --- {'prn': ['sptkfth;.zszSZtSdZ;z'], 'hw': "-'s"}
# 13 --- {'hw': '-ability'}
# 14 --- {'hw': '-able'}
# 15 --- {'prn': ['!dZ'], 'hw': '-age'}
# 16 --- {'hw': '-al'}
# 17 --- {'hw': '-al'}
# 18 --- {'hw': '-an'}
# 19 --- {'hw': '-an'}
# 20 --- {'prn': ['.ns'], 'hw': '-ance'}
# 21 --- {'prn': ['.nsi'], 'hw': '-ancy'}
# 22 --- {'prn': ['.nt'], 'hw': '-ant'}
# 23 --- {'hw': '-ant'}
# 24 --- {'prn': ['~'], 'hw': '-ar'}
# 25 --- {'hw': '-ary'}
# 26 --- {'hw': '-ary'}
# 27 --- {'hw': '-ation'}
# 28 --- {'hw': '-ative'}
# 29 --- {'hw': '-backed'}
# 30 --- {'prn': ["'sEntr!k"], 'hw': '-centric'}
# 31 --- {'prn': ['si'], 'hw': '-cy'}
# 32 --- {'prn': ['d.m'], 'hw': '-dom'}
# 33 --- {'hw': '-ean'}
# 34 --- {'prn': ['.d!dtd;tpktSfthsS;d;'], 'hw': '-ed'}
# 35 --- {'prn': ['i'], 'hw': '-ee'}
# 36 --- {'prn': ['i~'], 'hw': '-eer'}
# 37 --- {'prn': ['.n'], 'hw': '-en'}
# 38 --- {'hw': '-en'}
# 39 --- {'prn': ['.ns'], 'hw': '-ence'}
# 40 --- {'prn': ['.nsi'], 'hw': '-ency'}
# 41 --- {'prn': ['~'], 'hw': '-er'}
# 42 --- {'prn': ['~', 'i~j~', 'j~'], 'hw': '-er'}
# 43 --- {'prn': ['.ri'], 'hw': '-ery'}
# 44 --- {'prn': ['.z!zszStS;zv'], 'hw': '-es'}
# 45 --- {'hw': '-es'}
# 46 --- {'prn': ['.st!st'], 'hw': '-est'}
# 47 --- {'hw': '-eth'}
# 48 --- {'hw': '-ette'}
# 49 --- {'hw': '-ey'}
# 50 --- {'prn': [',fe!st'], 'hw': '-faced'}
# 51 --- {'prn': [',faj~d'], 'hw': '-fired'}
# 52 --- {'prn': [',foUld'], 'hw': '-fold'}
# 53 --- {'prn': ['f.l'], 'hw': '-ful'}
# 54 --- {'prn': ['fUl'], 'hw': '-ful'}
# 55 --- {'prn': ['fa!'], 'hw': '-fy'}
# 56 --- {'hw': '-goer'}
# 57 --- {'hw': '-going'}
# 58 --- {'prn_brit': 'y', 'prn': [',gr@f'], 'hw': '-graph'}
# 59 --- {'prn': ['gr.fi'], 'hw': '-graphy'}
# 60 --- {'prn': ['#,hUd'], 'hw': '-hood'}
# 61 --- {'hw': '-ian'}
# 62 --- {'hw': '-ibility'}
# 63 --- {'hw': '-ible'}
# 64 --- {'prn': ['!k'], 'hw': '-ic'}
# 65 --- {'hw': '-ic'}
# 66 --- {'prn': ['!k.l'], 'hw': '-ical'}
# 67 --- {'prn': ['!ks'], 'hw': '-ics'}
# 68 --- {'prn': ['a!d'], 'hw': '-ide'}
# 69 --- {'prn': ['i'], 'hw': '-ie'}
# 70 --- {'hw': '-ier'}
# 71 --- {'prn': ['.,fa!'], 'hw': '-ify'}
# 72 --- {'prn': ['!N!n'], 'hw': '-ing'}
# 73 --- {'hw': '-ing'}
# 74 --- {'hw': '-ion'}
# 75 --- {'hw': '-ise'}
# 76 --- {'hw': '-ish'}
# 77 --- {'prn': ['!z.m'], 'hw': '-ism'}
# 78 --- {'prn': ['!st'], 'hw': '-ist'}
# 79 --- {'hw': '-ist'}
# 80 --- {'prn': ['!st!k', '!st!k.l'], 'hw': '-istic'}
# 81 --- {'prn': ['a!t'], 'hw': '-ite'}
# 82 --- {'prn': ['a!t.s'], 'hw': '-itis'}
# 83 --- {'prn': ['.ti'], 'hw': '-ity'}
# 84 --- {'prn': ['!v'], 'hw': '-ive'}
# 85 --- {'prn': ['a!z'], 'hw': '-ize'}
# 86 --- {'prn': ['l.s'], 'hw': '-less'}
# 87 --- {'prn': ['l.t'], 'hw': '-let'}
# 88 --- {'prn': [',la!k'], 'hw': '-like'}
# 89 --- {'prn': ['l!N'], 'hw': '-ling'}
# 90 --- {'prn': [',l!vd'], 'hw': '-lived'}
# 91 --- {'hw': '-logy'}
# 92 --- {'prn': ['li'], 'hw': '-ly'}
# 93 --- {'hw': '-ly'}
# 94 --- {'prn': ['m.nt'], 'hw': '-ment'}
# 95 --- {'hw': '-meter'}
# 96 --- {'prn': ['moUst'], 'hw': '-most'}
# 97 --- {'prn': [',maUTHd'], 'hw': '-mouthed'}
# 98 --- {'hw': '-nd'}
# 99 --- {'prn': ['n.s'], 'hw': '-ness'}
# 100 --- {'prn': ['#,n!k'], 'hw': '-nik'}
# 101 --- {'prn': ['~'], 'hw': '-or'}
# 102 --- {'hw': '-ory'}
# 103 --- {'hw': '-ory'}
# 104 --- {'prn': ['.s'], 'hw': '-ous'}
# 105 --- {'prn': [',faj.l'], 'hw': '-phile'}
# 106 --- {'prn': ["'f!lij."], 'hw': '-philia'}
# 107 --- {'prn': [',foUb'], 'hw': '-phobe'}
# 108 --- {'prn': ["'foUbij."], 'hw': '-phobia'}
# 109 --- {'prn': ["'foUb!k"], 'hw': '-phobic'}
# 110 --- {'prn': [',foUn'], 'hw': '-phone'}
# 111 --- {'prn': [',pu:'], 'hw': '-poo'}
# 112 --- {'hw': '-rd'}
# 113 --- {'hw': '-ry'}
# 114 --- {'hw': '-s'}
# 115 --- {'hw': '-s'}
# 116 --- {'prn': [',S!p'], 'hw': '-ship'}
# 117 --- {'prn': [',SoUld~d'], 'hw': '-shouldered'}
# 118 --- {'prn': ['s.m'], 'hw': '-some'}
# 119 --- {'hw': '-some'}
# 120 --- {'prn': [',spi:k'], 'hw': '-speak'}
# 121 --- {'hw': '-st'}
# 122 --- {'prn': ['st~'], 'hw': '-ster'}
# 123 --- {'hw': '-th'}
# 124 --- {'prn': ["'toUd"], 'hw': '-toed'}
# 125 --- {'hw': '-ure'}
# 126 --- {'prn': ['w~d', 'w~dz'], 'hw': '-ward'}
# 127 --- {'hw': '-ward'}
# 128 --- {'prn': [',wa!z'], 'hw': '-wise'}
# 129 --- {'prn': ['i'], 'hw': '-y'}
# 130 --- {'prn': ['i'], 'hw': '-y'}
# 131 --- {'hw': '-y'}
# 132 --- {'hw': '-yer'}
# 133 --- {'prn': ["i'kle~"], 'hw': u'\xe9clair'}
# 134 --- {'prn': ["e!'lA:n"], 'hw': u'\xe9lan'}
# 135 --- {'prn': ["El'ni:nyoU"], 'hw': u'El Ni\xf1o'}
# 136 --- {'prn': ["'Em!,gre!"], 'hw': u'\xe9migr\xe9'}
# 137 --- {'prn': ["'A:n,tre!"], 'hw': u'entr\xe9e'}
# 138 --- {'prn_brit': 'y', 'prn': [",EkspoU'ze!"], 'hw': u'expos\xe9'}
# 139 --- {'prn': [",fi:,A:n'se!fi'A:n,se!"], 'hw': u'fianc\xe9'}
# 140 --- {'prn': [",fi:,A:n'se!fi'A:n,se!"], 'hw': u'fianc\xe9e'}
# 141 --- {'prn': ["flAm'be!"], 'hw': u'flamb\xe9'}
# 142 --- {'prn_brit': 'y', 'prn': [",@pl.'ke!"], 'hw': u'appliqu\xe9'}
# 143 --- {'hw': u'fra\xeeche'}
# 144 --- {'prn': [",A:,pre!'ski:"], 'hw': u'apr\xe8s-ski'}
# 145 --- {'prn': ["gru'je~"], 'hw': u'Gruy\xe8re'}
# 146 --- {'prn': ["h.'b!tS.,we!"], 'hw': u'habitu\xe9'}
# 147 --- {'prn_brit': 'y', 'prn': [",@t.'Se!"], 'hw': u'attach\xe9'}
# 148 --- {'hw': u'attach\xe9 case'}
# 149 --- {'prn': [",hA:l.'pe!njoU"], 'hw': u'jalape\xf1o'}
# 150 --- {'prn': ["lA'me!"], 'hw': u'lam\xe9'}
# 151 --- {'prn': ["'m@kr.,me!"], 'hw': u'macram\xe9'}
# 152 --- {'prn_brit': 'y', 'prn': ["mAn'ke!"], 'hw': u'manqu\xe9'}
# 153 --- {'prn': ["m.,tiri'El"], 'hw': u'mat\xe9riel'}
# 154 --- {'prn': ["me!'lA:ndZ"], 'hw': u'm\xe9lange'}
# 155 --- {'prn': ["me!'nA:ZA'trwA:", "me!'nA:ZA'trwA:"], 'hw': u'm\xe9nage \xe0 trois'}
# 156 --- {'prn': ["'mE,tje!"], 'hw': u'm\xe9tier'}
# 157 --- {'prn': ["'ne!"], 'hw': u'n\xe9e'}
# 158 --- {'prn_brit': 'y', 'prn': ["u'tre!"], 'hw': u'outr\xe9'}
# 159 --- {'prn_brit': 'y', 'prn': [",pe!p~m.'Se!"], 'hw': u'papier-m\xe2ch\xe9'}
# 160 --- {'prn_brit': 'y', 'prn': ["p@'se!"], 'hw': u'pass\xe9'}
# 161 --- {'prn_brit': 'y', 'prn': ["pA'te!"], 'hw': u'p\xe2t\xe9'}
# 162 --- {'prn': ["pi,Esd.r.,zi:'stA:ns", "pi,Esd.r.,zi:'stA:ns"], 'hw': u'pi\xe8ce de r\xe9sistance'}
# 163 --- {'prn': ["'pi:nj.koU'lA:d."], 'hw': u'pi\xf1a colada'}
# 164 --- {'prn': ["pin'jA:t."], 'hw': u'pi\xf1ata'}
# 165 --- {'prn': ["pre!'si:", "pre!'si:z", "pre!'si:z"], 'hw': u'pr\xe9cis'}
# 166 --- {'prn': ["'proUt.,Ze!"], 'hw': u'prot\xe9g\xe9'}
# 167 --- {'prn': ["'proUt.,Ze!"], 'hw': u'prot\xe9g\xe9e'}
# 168 --- {'prn': [",re!,zoUn'dEtr.", ",re!,zoUnz'dEtr."], 'hw': u"raison d'\xeatre"}
# 169 --- {'prn_brit': 'y', 'prn': ["r.,Se~'Se!"], 'hw': u'recherch\xe9'}
# 170 --- {'prn': [",bEt'nwA~", ",bEt'nwA~z"], 'hw': u'b\xeate noire'}
# 171 --- {'prn_brit': 'y', 'prn': ["'rEz.,me!"], 'hw': u'r\xe9sum\xe9'}
# 172 --- {'prn': ["r!'ske!"], 'hw': u'risqu\xe9'}
# 173 --- {'prn_brit': 'y', 'prn': ["roU'ze!"], 'hw': u'ros\xe9'}
# 174 --- {'prn_brit': 'y', 'prn': ["sA'te!"], 'hw': u'saut\xe9'}
# 175 --- {'hw': u'saut\xe9'}
# 176 --- {'prn': ["'se!,A:ns"], 'hw': u's\xe9ance'}
# 177 --- {'prn_brit': 'y', 'prn': ["blA'ze!"], 'hw': u'blas\xe9'}
# 178 --- {'prn': ["su'fle!"], 'hw': u'souffl\xe9'}
# 179 --- {'prn': ["'su:p,sA:n"], 'hw': u'soup\xe7on'}
# 180 --- {'prn': [",tEt.'tEt"], 'hw': u't\xeate-\xe0-t\xeate'}
# 181 --- {'prn': [",boUn@p.'ti:"], 'hw': u'bon app\xe9tit'}
# 182 --- {'prn': ["tu'Se!"], 'hw': u'touch\xe9'}
# 183 --- {'hw': u'transport caf\xe9'}
# 184 --- {'prn': ["'u:b~"], 'hw': u'\xfcber-'}
# 185 --- {'prn_brit': 'y', 'prn': ["v!'ku:nj."], 'hw': u'vicu\xf1a'}
# 186 --- {'prn': ["vwA'lA:"], 'hw': u'voil\xe0'}
# 187 --- {'hw': u'br\xfbl\xe9e'}
# 188 --- {'prn_brit': 'y', 'prn': ["k@'fe!"], 'hw': u'caf\xe9'}
# 189 --- {'prn': ["'k@n.pi'k@n.,pe!"], 'hw': u'canap\xe9'}
# 190 --- {'prn': [",kA:zs.'lEbr.", ",kAz:s.'lEbr."], 'hw': u'cause c\xe9l\xe8bre'}
# 191 --- {'hw': u'c\xe9l\xe8bre'}
# 192 --- {'prn': ["SA~,Ze!d.'fe~", "SA~,Ze!d.'fe~"], 'hw': u"charg\xe9 d'affaires"}
# 193 --- {'prn_brit': 'y', 'prn': ["S@'toU", "S@'toUz"], 'hw': u'ch\xe2teau'}
# 194 --- {'prn': ["kli'Se!'kli:,Se!", "kli'Se!d"], 'hw': u'clich\xe9'}
# 195 --- {'prn': ["k.'mju:n.,ke!"], 'hw': u'communiqu\xe9'}
# 196 --- {'prn': [',A:,lA:'], 'hw': u'\xe0 la'}
# 197 --- {'prn': [",A:l.'kA~t"], 'hw': u'\xe0 la carte'}
# 198 --- {'prn': [",A:l.'moUd"], 'hw': u'\xe0 la mode'}
# 199 --- {'prn_brit': 'y', 'prn': [",kA:ns.'me!"], 'hw': u'consomm\xe9'}
# 200 --- {'prn': [",ku:d.'grA:s", ",ku:d.'grA:s"], 'hw': u'coup de gr\xe2ce'}
# 201 --- {'prn': [",ku:,de!'tA:", ",ku:,de!'tA:"], 'hw': u"coup d'\xe9tat"}
# 202 --- {'prn': ["'krES"], 'hw': u'cr\xe8che'}
# 203 --- {'prn': [",krEmAN'gle!z"], 'hw': u'cr\xe8me anglaise'}
# 204 --- {'prn': [",krEmbru'le!"], 'hw': u'cr\xe8me br\xfbl\xe9e'}
# 205 --- {'prn': [",krEm,ker.'mEl"], 'hw': u'cr\xe8me caramel'}
# 206 --- {'prn': ["'krEmd.lA'krEm"], 'hw': u'cr\xe8me de la cr\xe8me'}
# 207 --- {'prn_brit': 'y', 'prn': ["'krEmd.'mEnth"], 'hw': u'cr\xe8me de menthe'}
# 208 --- {'prn': ["'krEm'frES"], 'hw': u'cr\xe8me fra\xeeche'}
# 209 --- {'prn': [",kru:d!'te!"], 'hw': u'crudit\xe9s'}
# 210 --- {'prn_brit': 'y', 'prn': ["'sa!b~k@'fe!"], 'hw': u'cybercaf\xe9'}
# 211 --- {'prn': ["de!,kA:l.'tA:Z", "de!,kA:l'te!"], 'hw': u'd\xe9colletage'}
# 212 --- {'prn': [",de!,ZA:'vu:"], 'hw': u'd\xe9j\xe0 vu'}
# 213 --- {'prn': ["de!'tA:nt"], 'hw': u'd\xe9tente'}
# 214 --- {'prn': ["d.,vo~'se!"], 'hw': u'divorc\xe9'}
# 215 --- {'prn': ["d.,vo~'se!"], 'hw': u'divorc\xe9e'}
# 216 --- {'prn': ["'dA:p.l,g@Ng~"], 'hw': u'doppelg\xe4nger'}
# 217 --- {'prn': ["'thri:'di:"], 'hw': '3-D'}
# 218 --- {'prn': ["'fo~'e!tS"], 'hw': '4-H'}
# 219 --- {'prn': [",fo~,oU,w^n'ke!"], 'hw': '401(k)'}
# 220 --- {'prn': ["'fo~ba!,fo~"], 'hw': '4x4'}
# 221 --- {'prn': [",e!t'h^ndr.d#"], 'hw': '800 number'}
# 222 --- {'prn': ['.'], 'hw': 'a-'}
# 223 --- {'hw': 'a-'}
# 224 --- {'prn': ["'e!,bA:m"], 'hw': 'A-bomb'}
# 225 --- {'prn': ["'e!,la!n"], 'hw': 'A-line'}
# 226 --- {'prn': ["'e!,l!st"], 'hw': 'A-list'}
# 227 --- {'prn': [",e!oU'ke!"], 'hw': 'A-OK'}
# 228 --- {'prn': ["'e!"], 'hw': 'a'}
# 229 --- {'prn': [".'e!", ".n'@n"], 'hw': 'a'}
# 230 --- {'hw': 'a.m.'}
# 231 --- {'prn': [",e!,En'^TH~"], 'hw': 'A. N. Other'}
# 232 --- {'prn': ["'e!'w^n"], 'hw': 'A1'}
# 233 --- {'hw': 'AA'}
# 234 --- {'hw': 'AAA'}
# 235 --- {'prn': ["'A:"], 'hw': 'aah'}
# 236 --- {'hw': 'aah'}
# 237 --- {'prn': ["'A~d,vA~k"], 'hw': 'aardvark'}
# 238 --- {'hw': 'AARP'}
# 239 --- {'hw': 'ab.'}
# 240 --- {'prn': ["'@b"], 'hw': 'ab'}
# 241 --- {'prn': [".'b@k"], 'hw': 'aback'}
# 242 --- {'prn': ["'@b.k.s", '#,sa!'], 'hw': 'abacus'}
# 243 --- {'prn': [",@b.'loUni"], 'hw': 'abalone'}
# 244 --- {'prn': [".'b@nd.n", ".'b@nd.nm.nt"], 'hw': 'abandon'}
# 245 --- {'hw': 'abandon'}
# 246 --- {'prn': [".'b@nd.nd"], 'hw': 'abandoned'}
# 247 --- {'prn': [".'be!s"], 'hw': 'abase'}
# 248 --- {'prn': [".'b@St"], 'hw': 'abashed'}
# 249 --- {'prn': [".'be!t", ".'be!tm.nt"], 'hw': 'abate'}
# 250 --- {'prn': ["'@b.,twA~"], 'hw': 'abattoir'}
# 251 --- {'prn': ["'@b.s"], 'hw': 'abbess'}
# 252 --- {'prn': ["'@bi"], 'hw': 'abbey'}
# 253 --- {'prn': ["'@b.t"], 'hw': 'abbot'}
# 254 --- {'hw': 'abbr'}
# 255 --- {'prn': [".'bri:vi,e!t"], 'hw': 'abbreviate'}
# 256 --- {'prn': [".,bri:vi'e!S.n"], 'hw': 'abbreviation'}
# 257 --- {'prn': [",e!,bi'si:"], 'hw': 'ABC'}
# 258 --- {'hw': 'ABC'}
# 259 --- {'prn': ["'@bd!,ke!t", ",@bd!'ke!S.n"], 'hw': 'abdicate'}
# 260 --- {'prn': ["'@bd.m.n", "@b'dA:m.nl-"], 'hw': 'abdomen'}
# 261 --- {'prn': ["@b'd^kt", ",@b,d^k'ti:", "@b'd^kS.n", "@b'd^kt~"], 'hw': 'abduct'}
# 262 --- {'prn': [".'bEd"], 'hw': 'abed'}
# 263 --- {'prn': [".'ber.nt"], 'hw': 'aberrant'}
# 264 --- {'prn': [",@b.'re!S.n"], 'hw': 'aberration'}
# 265 --- {'prn': [".'bEt"], 'hw': 'abet'}
# 266 --- {'prn': [".'bej.ns"], 'hw': 'abeyance'}
# 267 --- {'prn': [".b'ho~", ".b'hor.ns"], 'hw': 'abhor'}
# 268 --- {'prn': [".b'hor.nt"], 'hw': 'abhorrent'}
# 269 --- {'prn': [".'ba!d"], 'hw': 'abide'}
# 270 --- {'prn': [".'ba!d!N"], 'hw': 'abiding'}
# 271 --- {'prn': [".'b!l.ti"], 'hw': 'ability'}
# 272 --- {'prn': ["'@b,dZEkt", "'@b,dZEktli"], 'hw': 'abject'}
# 273 --- {'prn': ["@b'dZu~"], 'hw': 'abjure'}
# 274 --- {'prn': [".'ble!z"], 'hw': 'ablaze'}
# 275 --- {'prn': [",e!b.l'bA:did"], 'hw': 'able-bodied'}
# 276 --- {'prn': ["'e!b.l"], 'hw': 'able'}
# 277 --- {'prn': [".'blu:S.n"], 'hw': 'ablution'}
# 278 --- {'prn': ["'e!b.li"], 'hw': 'ably'}
# 279 --- {'prn': ["@b'no~m.l"], 'hw': 'abnormal'}
# 280 --- {'prn': [",@bn~'m@l.ti"], 'hw': 'abnormality'}
# 281 --- {'prn': [".'bo~d"], 'hw': 'aboard'}
# 282 --- {'hw': 'aboard'}
# 283 --- {'prn': [".'boUd"], 'hw': 'abode'}
# 284 --- {'hw': 'abode'}
# 285 --- {'prn': [".'bA:l!S"], 'hw': 'abolish'}
# 286 --- {'prn': [",@b.'l!Sn-"], 'hw': 'abolition'}
# 287 --- {'prn': [",@b.'l!Sn-!st"], 'hw': 'abolitionist'}
# 288 --- {'prn': [".'bA:m.n.b.l", ".'bA:m.n.bli"], 'hw': 'abominable'}
# 289 --- {'hw': 'abominable snowman'}
# 290 --- {'prn': [".'bA:m.,ne!t"], 'hw': 'abominate'}
# 291 --- {'prn': [".,bA:m.'ne!S.n"], 'hw': 'abomination'}
# 292 --- {'prn': [",@b.'r!dZ.nl-"], 'hw': 'aboriginal'}
# 293 --- {'hw': 'aboriginal'}
# 294 --- {'prn': [",@b.'r!dZ.ni"], 'hw': 'aborigine'}
# 295 --- {'prn': [".'bo~t"], 'hw': 'abort'}
# 296 --- {'prn': [".'bo~S.n"], 'hw': 'abortion'}
# 297 --- {'prn': [".'bo~S.n!st"], 'hw': 'abortionist'}
# 298 --- {'prn': [".'bo~t!v"], 'hw': 'abortive'}
# 299 --- {'prn': [".'baUnd"], 'hw': 'abound'}
# 300 --- {'prn': [".'baUt'fe!s"], 'hw': 'about-face'}
# 301 --- {'prn': [".'baUt't~n"], 'hw': 'about-turn'}
# 302 --- {'prn': [".'baUt"], 'hw': 'about'}
# 303 --- {'hw': 'about'}
# 304 --- {'hw': 'about'}
# 305 --- {'prn': [".'b^v"], 'hw': 'above'}
# 306 --- {'hw': 'above'}
# 307 --- {'hw': 'above'}
# 308 --- {'prn': [".'b^v,bo~d"], 'hw': 'aboveboard'}
# 309 --- {'prn': [".'b^v,graUnd"], 'hw': 'aboveground'}
# 310 --- {'prn': [",@br.k.'d@br."], 'hw': 'abracadabra'}
# 311 --- {'prn': [".'bre!d"], 'hw': 'abrade'}
# 312 --- {'prn': [".'bre!Z.n"], 'hw': 'abrasion'}
# 313 --- {'prn': [".'bre!s!v"], 'hw': 'abrasive'}
# 314 --- {'hw': 'abrasive'}
# 315 --- {'prn': [".'brEst"], 'hw': 'abreast'}
# 316 --- {'prn': [".'br!dZ", ".'br!dZm.nt"], 'hw': 'abridge'}
# 317 --- {'prn': [".'brA:d"], 'hw': 'abroad'}
# 318 --- {'prn': ["'@br.,ge!t", ",@br.'ge!S.n"], 'hw': 'abrogate'}
# 319 --- {'prn': [".'br^pt"], 'hw': 'abrupt'}
# 320 --- {'hw': 'abs'}
# 321 --- {'hw': 'ABS'}
# 322 --- {'prn': ["'@b,sEs", "'@b,sEst"], 'hw': 'abscess'}
# 323 --- {'prn': ["@b'skA:nd"], 'hw': 'abscond'}
# 324 --- {'prn': ["'@b,se!l"], 'hw': 'abseil'}
# 325 --- {'prn': ["'@bs.ns"], 'hw': 'absence'}
# 326 --- {'prn': ["'@bs.nt"], 'hw': 'absent'}
# 327 --- {'prn': ["@b'sEnt"], 'hw': 'absent'}
# 328 --- {'prn': ["'@bs.nt"], 'hw': 'absent'}
# 329 --- {'prn': [",@bs.n'ti:"], 'hw': 'absentee'}
# 330 --- {'prn': [",@bs.n'ti:,!z.m"], 'hw': 'absenteeism'}
# 331 --- {'hw': 'absentee ballot'}
# 332 --- {'hw': 'absentee landlord'}
# 333 --- {'hw': 'absentia'}
# 334 --- {'prn': [",@bs.nt'ma!nd.d"], 'hw': 'absentminded'}
# 335 --- {'prn': ["'@b,s!nth"], 'hw': 'absinthe'}
# 336 --- {'prn': ["'@bs.,lu:t"], 'hw': 'absolute'}
# 337 --- {'prn': ["'@bs.,lu:tli"], 'hw': 'absolutely'}
# 338 --- {'hw': 'absolute zero'}
# 339 --- {'prn': [",@bs.'lu:S.n"], 'hw': 'absolution'}
# 340 --- {'prn': [".b'zA:lv"], 'hw': 'absolve'}
# 341 --- {'prn': [".b'so~b", ".b'so~b.b.l", ".b'so~pS.n"], 'hw': 'absorb'}
# 342 --- {'prn': [".b'so~b.nt", ".b'so~b.nsi"], 'hw': 'absorbent'}
# 343 --- {'prn': [".b'ste!n"], 'hw': 'abstain'}
# 344 --- {'prn': ["@b'sti:mij.s"], 'hw': 'abstemious'}
# 345 --- {'prn': [".b'stEnS.n"], 'hw': 'abstention'}
# 346 --- {'prn': ["'@bst.n.ns", "'@bst.n.nt"], 'hw': 'abstinence'}
# 347 --- {'prn': ["@b'str@kt'@b,str@kt", "@b'str@ktli", "@b'str@ktn.s"], 'hw': 'abstract'}
# is a homograph
# 348 --- {'prn': ["'@b,str@kt"], 'hw': 'abstract'}
# is a homograph
# 349 --- {'prn': ["@b'str@kt"], 'hw': 'abstract'}
# is a homograph
# 350 --- {'prn': ["@b'str@kt.d"], 'hw': 'abstracted'}
# 351 --- {'prn': ["@b'str@kS.n"], 'hw': 'abstraction'}
# 352 --- {'prn': [".b'stru:s"], 'hw': 'abstruse'}
# 353 --- {'prn': [".b's~d", ".b's~d.ti"], 'hw': 'absurd'}
# 354 --- {'prn': [".'b^nd.ns"], 'hw': 'abundance'}
# 355 --- {'prn': [".'b^nd.nt"], 'hw': 'abundant'}
# 356 --- {'prn': [".'bju:z"], 'hw': 'abuse'}
# is a homograph
# 357 --- {'prn': [".'bju:s"], 'hw': 'abuse'}
# is a homograph
# 358 --- {'prn': [".'bju:s!v"], 'hw': 'abusive'}
# 359 --- {'prn': [".'b^t", ".'b^t~"], 'hw': 'abut'}
# 360 --- {'prn': [".'b^tm.nt"], 'hw': 'abutment'}
# 361 --- {'prn': [".'b^z"], 'hw': 'abuzz'}
# 362 --- {'prn': [".'b!zm.l"], 'hw': 'abysmal'}
# 363 --- {'prn': [".'b!s"], 'hw': 'abyss'}
# 364 --- {'hw': 'AC'}
# 365 --- {'prn': [".'ke!S."], 'hw': 'acacia'}
# 366 --- {'prn': [",@k.'di:mij."], 'hw': 'academia'}
# 367 --- {'prn': [",@k.'dEm!k", ",@k.'dEm!kli"], 'hw': 'academic'}
# 368 --- {'hw': 'academic'}
# 369 --- {'hw': 'academic year'}
# 370 --- {'prn': [".'k@d.mi"], 'hw': 'academy'}
# 371 --- {'hw': 'Academy Award'}
# 372 --- {'prn': ["@k'si:d"], 'hw': 'accede'}
# 373 --- {'prn': ["!k'sEl.,re!t"], 'hw': 'accelerate'}
# 374 --- {'prn': ["!k,sEl.'re!S.n"], 'hw': 'acceleration'}
# 375 --- {'prn': ["!k'sEl.,re!t~"], 'hw': 'accelerator'}
# 376 --- {'prn_brit': 'y', 'prn': ["'@k,sEnt"], 'hw': 'accent'}
# 377 --- {'prn_brit': 'y', 'prn': ["'@k,sEnt"], 'hw': 'accent'}
# 378 --- {'hw': 'accented'}
# 379 --- {'prn': ["@k'sEntS.,we!t", "!k,sEntS.'we!S.n"], 'hw': 'accentuate'}
# 380 --- {'hw': 'accent mark'}
# 381 --- {'prn': ["!k'sEpt", "!k'sEpt~"], 'hw': 'accept'}
# 382 --- {'prn': ["!k'sEpt.b.#", "!k,sEpt.'b!l.ti", "!k'sEpt.bli"], 'hw': 'acceptable'}
# 383 --- {'prn': ["!k'sEpt.ns"], 'hw': 'acceptance'}
# 384 --- {'prn': ["'@k,sEs"], 'hw': 'access'}
# 385 --- {'hw': 'access'}
# 386 --- {'prn': ["!k'sEs.b.l", "!k,sEs.'b!l.ti", "!k'sEs.bli"], 'hw': 'accessible'}
# 387 --- {'prn': ["!k'sES.n"], 'hw': 'accession'}
# 388 --- {'prn': ["!k'sEs.,ra!z"], 'hw': 'accessorize'}
# 389 --- {'prn': ["!k'sEs.ri"], 'hw': 'accessory'}
# 390 --- {'hw': 'access time'}
# 391 --- {'hw': 'accident-prone'}
# 392 --- {'prn': ["'@ks.d.nt"], 'hw': 'accident'}
# 393 --- {'prn': [",@ks.'dEntl-", ",@ks.'dEntl-i"], 'hw': 'accidental'}
# 394 --- {'prn': [".'kle!m"], 'hw': 'acclaim'}
# 395 --- {'hw': 'acclaim'}
# 396 --- {'prn': [",@kl.'me!S.n"], 'hw': 'acclamation'}
# 397 --- {'prn_brit': 'y', 'prn': ["'@kl.,me!t", ",@kl.'me!S.n"], 'hw': 'acclimate'}
# 398 --- {'prn_brit': 'y', 'prn': [".'kla!m.,ta!z", ".,kla!m.t.'ze!S.n"], 'hw': 'acclimatize'}
# 399 --- {'prn': ["'@k.,le!d"], 'hw': 'accolade'}
# 400 --- {'prn': [".'kA:m.,de!t"], 'hw': 'accommodate'}
# 401 --- {'hw': 'accommodating'}
# 402 --- {'prn': [".,kA:m.'de!S.n"], 'hw': 'accommodation'}
# 403 --- {'prn': [".'k^mp.nim.nt"], 'hw': 'accompaniment'}
# 404 --- {'prn': [".'k^mp.n!st"], 'hw': 'accompanist'}
# 405 --- {'prn': [".'k^mp.ni"], 'hw': 'accompany'}
# 406 --- {'hw': 'accompli'}
# 407 --- {'prn': [".'kA:mpl.s"], 'hw': 'accomplice'}
# 408 --- {'prn': [".'kA:mpl!S", ".'khAmpl!S.b.#"], 'hw': 'accomplish'}
# 409 --- {'hw': 'accomplished'}
# 410 --- {'prn': [".'kA:mpl!Sm.nt"], 'hw': 'accomplishment'}
# 411 --- {'prn': [".'ko~d"], 'hw': 'accord'}
# 412 --- {'hw': 'accord'}
# 413 --- {'prn': [".'ko~dn-s"], 'hw': 'accordance'}
# 414 --- {'prn': [".'ko~d!Nli"], 'hw': 'accordingly'}
# 415 --- {'hw': 'according to'}
# 416 --- {'prn': [".'ko~dij.n", ".'ko~dij.n!st"], 'hw': 'accordion'}
# 417 --- {'prn': [".'kA:st"], 'hw': 'accost'}
# 418 --- {'prn': [".'kaUnt"], 'hw': 'account'}
# 419 --- {'hw': 'account'}
# 420 --- {'prn': [".'kaUnt.b.l", ".,kh@Unt.'b!l.ddi"], 'hw': 'accountable'}
# 421 --- {'prn': [".'kaUntn-t"], 'hw': 'accountant'}
# 422 --- {'prn': [".'kaUnt!N"], 'hw': 'accounting'}
# 423 --- {'prn': [".'ku:t~d"], 'hw': 'accoutred'}
# 424 --- {'prn': [".'ku:tr.m.nt.'ku:t~m.nt"], 'hw': 'accoutrement'}
# 425 --- {'prn': [".'krEd.t", ".,krEd.'te!S.n"], 'hw': 'accredit'}
# 426 --- {'prn': [".'kri:S.n"], 'hw': 'accretion'}
# 427 --- {'prn': [".'kru:", ".'kru:w.l"], 'hw': 'accrue'}
# 428 --- {'prn': [".'kju:mj.,le!t", ".,kju:mj.'le!S.n"], 'hw': 'accumulate'}
# 429 --- {'prn': [".'kju:mj.l.t!v"], 'hw': 'accumulative'}
# 430 --- {'prn': ["'@kj.r.si"], 'hw': 'accuracy'}
# 431 --- {'prn': ["'@kj.r.t"], 'hw': 'accurate'}
# 432 --- {'prn': [".'k~st.'k~s.d"], 'hw': 'accursed'}
# 433 --- {'prn': [",@kj.'ze!S.n"], 'hw': 'accusation'}
# 434 --- {'prn': [".'khju:z.t!v"], 'hw': 'accusative'}
# 435 --- {'prn_brit': 'y', 'prn': [".'kju:z.,tori"], 'hw': 'accusatory'}
# 436 --- {'prn': [".'kju:z", ".'khju:z!Nli"], 'hw': 'accuse'}
# 437 --- {'hw': 'accused'}
# 438 --- {'prn': [".'k^st.m"], 'hw': 'accustom'}
# 439 --- {'prn': [".'k^st.md"], 'hw': 'accustomed'}
# 440 --- {'prn': ["'e!s"], 'hw': 'ace'}
# 441 --- {'hw': 'ace'}
# 442 --- {'prn': [".'s~b!k", ".'s~b!kli"], 'hw': 'acerbic'}
# 443 --- {'prn': [".,si:t.'m!n.f.n"], 'hw': 'acetaminophen'}
# 444 --- {'prn': [".'sEtl-.n"], 'hw': 'acetylene'}
# 445 --- {'prn': ["'e!k"], 'hw': 'ache'}
# 446 --- {'prn': ["'e!ki"], 'hw': 'ache'}
# 447 --- {'prn': [".'tSi:v", ".'tSi:v.b.#"], 'hw': 'achieve'}
# 448 --- {'prn': [".'tSi:vm.nt"], 'hw': 'achievement'}
# 449 --- {'prn': [".'tSi:v~"], 'hw': 'achiever'}
# 450 --- {'prn': [".'k!liz#"], 'hw': "Achilles' heel"}
# 451 --- {'hw': 'Achilles tendon'}
# 452 --- {'prn': [".'tSu:"], 'hw': 'achoo'}
# 453 --- {'prn': ["'@s.d"], 'hw': 'acid'}
# 454 --- {'prn': [".'s!d.ti"], 'hw': 'acid'}
# 455 --- {'prn': [".'s!d!k"], 'hw': 'acidic'}
# 456 --- {'prn': [".'s!d.,fa!", ".,s!d.f.'ke!S.n"], 'hw': 'acidify'}
# 457 --- {'hw': 'acid rain'}
# 458 --- {'hw': 'acid test'}
# 459 --- {'prn': ["!k'nA:l!dZ"], 'hw': 'acknowledge'}
# 460 --- {'prn': ["!k'nA:l!dZm.nt"], 'hw': 'acknowledgment'}
# 461 --- {'prn': ["'@kmi"], 'hw': 'acme'}
# 462 --- {'prn': ["'@kni"], 'hw': 'acne'}
# 463 --- {'prn': ["'@k.,la!t"], 'hw': 'acolyte'}
# 464 --- {'prn': ["'e!,ko~n"], 'hw': 'acorn'}
# 465 --- {'hw': 'acorn squash'}
# 466 --- {'prn': [".'ku:st!k", ".'ku:st!k.l", ".'ku:st!kli"], 'hw': 'acoustic'}
# 467 --- {'prn': [".'ku:st!ks"], 'hw': 'acoustics'}
# 468 --- {'prn': [".'kwe!nt"], 'hw': 'acquaint'}
# 469 --- {'prn': [".'kwe!ntn-s"], 'hw': 'acquaintance'}
# 470 --- {'hw': 'acquainted'}
# 471 --- {'prn': [",@kwi'Es", ",@kwi'Esn-s"], 'hw': 'acquiesce'}
# 472 --- {'prn': [",@kwi'Esn-t"], 'hw': 'acquiescent'}
# 473 --- {'prn': [".'kwaj~"], 'hw': 'acquire'}
# 474 --- {'hw': 'acquired immune deficiency syndrome'}
# 475 --- {'prn': [",@kw.'z!S.n"], 'hw': 'acquisition'}
# 476 --- {'prn': [".'kw!z.t!v"], 'hw': 'acquisitive'}
# 477 --- {'prn': [".'kw!t"], 'hw': 'acquit'}
# 478 --- {'prn': [".'kw!tl-"], 'hw': 'acquittal'}
# 479 --- {'prn': ["'e!k~"], 'hw': 'acre'}
# 480 --- {'prn': ["'e!k.r!dZ"], 'hw': 'acreage'}
# 481 --- {'prn': ["'@kr.d"], 'hw': 'acrid'}
# 482 --- {'prn': [",@kr.'moUnij.s"], 'hw': 'acrimonious'}
# 483 --- {'prn_brit': 'y', 'prn': ["'@kr.,moUni"], 'hw': 'acrimony'}
# 484 --- {'prn': ["'@kr.,b@t", ",@kr.'b@t!k", ",@kr.'b@t!kli"], 'hw': 'acrobat'}
# 485 --- {'prn': [",@kr.'b@t!ks"], 'hw': 'acrobatics'}
# 486 --- {'prn': ["'@kr.,n!m"], 'hw': 'acronym'}
# 487 --- {'hw': 'across-the-board'}
# 488 --- {'prn': [".'khrA:s"], 'hw': 'across'}
# 489 --- {'hw': 'across'}
# 490 --- {'prn': [".'kr!l!k"], 'hw': 'acrylic'}
# 491 --- {'prn': ["'@kt"], 'hw': 'act'}
# 492 --- {'hw': 'act'}
# 493 --- {'hw': 'ACT'}
# 494 --- {'prn': ["'@kt!N"], 'hw': 'acting'}
# 495 --- {'hw': 'acting'}
# 496 --- {'hw': 'action-packed'}
# 497 --- {'prn': ["'@kS.n"], 'hw': 'action'}
# 498 --- {'prn': ["'@kS.n.b.l"], 'hw': 'actionable'}
# 499 --- {'hw': 'action figure'}
# 500 --- {'hw': 'action replay'}
# 501 --- {'hw': 'action verb'}
# 502 --- {'prn': ["'@kt.,ve!t", ",@kt.'ve!S.n"], 'hw': 'activate'}
# 503 --- {'prn': ["'@kt!v"], 'hw': 'active'}
# 504 --- {'prn': ["'@kt!v!st", "'@kt!,v!z.m"], 'hw': 'activist'}
# 505 --- {'prn': ["@k't!v.ti"], 'hw': 'activity'}
# 506 --- {'prn': ["'@kt~"], 'hw': 'actor'}
# 507 --- {'prn': ["'@ktr.s"], 'hw': 'actress'}
# 508 --- {'prn': ["'@ktS.w.l"], 'hw': 'actual'}
# 509 --- {'prn': [",@ktS.'w@l.ti"], 'hw': 'actuality'}
# 510 --- {'prn': ["'@ktS.w.li"], 'hw': 'actually'}
# 511 --- {'prn_brit': 'y', 'prn': ["'@ktS.,weri", ",@ktS.'werij.#"], 'hw': 'actuary'}
# 512 --- {'prn': ["'@ktS.,we!t"], 'hw': 'actuate'}
# 513 --- {'prn': [".'kju:w.ti"], 'hw': 'acuity'}
# 514 --- {'prn': [".'kju:m.n"], 'hw': 'acumen'}
# 515 --- {'prn': ["'@kj.,prES~"], 'hw': 'acupressure'}
# 516 --- {'prn': ["'@kj.,p^NktS~", "'@kj.,p^NktS.r!st"], 'hw': 'acupuncture'}
# 517 --- {'prn': [".'kju:t"], 'hw': 'acute'}
# 518 --- {'prn': ["'@d'l!b"], 'hw': 'ad-lib'}
# 519 --- {'prn': ["'@d"], 'hw': 'ad'}
# 520 --- {'hw': 'AD'}
# 521 --- {'prn': ["'@d!dZ"], 'hw': 'adage'}
# 522 --- {'prn': [".'dA:dZijoU"], 'hw': 'adagio'}
# 523 --- {'hw': 'adagio'}
# 524 --- {'hw': "Adam's apple"}
# 525 --- {'prn': ["'@d.m"], 'hw': 'Adam'}
# 526 --- {'prn': ["'@d.m.nt"], 'hw': 'adamant'}
# 527 --- {'prn': [".'d@pt"], 'hw': 'adapt'}
# 528 --- {'prn': [".'d@pt.b.l", ".,d@pt.'b!l.ti"], 'hw': 'adaptable'}
# 529 --- {'prn': [",@,d@p'te!S.n"], 'hw': 'adaptation'}
# 530 --- {'prn': [".'d@pt~"], 'hw': 'adapter'}
# 531 --- {'prn': ["'@d,A:n"], 'hw': 'add-on'}
# 532 --- {'prn': ["'@d"], 'hw': 'add'}
# 533 --- {'hw': 'ADD'}
# 534 --- {'prn': [".'dEnd.m", "#'dEnd."], 'hw': 'addendum'}
# 535 --- {'prn': ["'@d~"], 'hw': 'adder'}
# 536 --- {'prn': ["'@d!kt"], 'hw': 'addict'}
# 537 --- {'prn': [".'d!kt.d"], 'hw': 'addicted'}
# 538 --- {'prn': [".'d!kS.n"], 'hw': 'addiction'}
# 539 --- {'prn': [".'d!kt!v"], 'hw': 'addictive'}
# 540 --- {'prn': [".'d!S.n"], 'hw': 'addition'}
# 541 --- {'prn': [".'d!S.nl-", ".'d!S.nl-i"], 'hw': 'additional'}
# 542 --- {'prn': ["'@d.t!v"], 'hw': 'additive'}
# 543 --- {'prn': ["'@dl-"], 'hw': 'addle'}
# 544 --- {'prn': [".'drEs"], 'hw': 'address'}
# 545 --- {'prn': [".'drEs'@,drEs"], 'hw': 'address'}
# 546 --- {'prn': [",@,drE'si:"], 'hw': 'addressee'}
# 547 --- {'hw': 'address book'}
# 548 --- {'prn_brit': 'y', 'prn': [".'du:s"], 'hw': 'adduce'}
# 549 --- {'prn': ["'@d.,no!dz", ",@d.'no!dl-"], 'hw': 'adenoids'}
# 550 --- {'prn': [".'dEpt"], 'hw': 'adept'}
# 551 --- {'prn': ["'@,dEpt"], 'hw': 'adept'}
# 552 --- {'prn': ["'@d!kw.t", "'@d!kw.si"], 'hw': 'adequate'}
# 553 --- {'prn': ["@d'hi~"], 'hw': 'adhere'}
# 554 --- {'prn': ["@d'hir.ns"], 'hw': 'adherence'}
# 555 --- {'prn': ["@d'hir.nt"], 'hw': 'adherent'}
# 556 --- {'prn': ["@d'hi:Z.n"], 'hw': 'adhesion'}
# 557 --- {'prn': ["@d'hi:s!v"], 'hw': 'adhesive'}
# 558 --- {'hw': 'adhesive'}
# 559 --- {'prn': [".'du:.'dju:"], 'hw': 'adieu'}
# 560 --- {'prn': [".'du:.'dju:"], 'hw': 'adieu'}
# 561 --- {'prn_brit': 'y', 'prn': [",A:di'oUs"], 'hw': 'adios'}
# 562 --- {'hw': 'adj'}
# 563 --- {'prn': [".'dZe!sn-t"], 'hw': 'adjacent'}
# 564 --- {'prn': ["'@dZ!kt!v", ",@dZ!k'ta!v.l"], 'hw': 'adjective'}
# 565 --- {'prn': [".'dZo!n"], 'hw': 'adjoin'}
# 566 --- {'prn': [".'dZ~n", ".'dZ~nm.nt"], 'hw': 'adjourn'}
# 567 --- {'prn': [".'dZ^dZ"], 'hw': 'adjudge'}
# 568 --- {'prn': [".'dZu:d!,ke!t", ".,dZu:d!'ke!S.n", ".'dZu:d!,ke!t~"], 'hw': 'adjudicate'}
# 569 --- {'prn': ["'@,dZ^Nkt"], 'hw': 'adjunct'}
# 570 --- {'hw': 'adjunct'}
# 571 --- {'prn': [".'dZu~"], 'hw': 'adjure'}
# 572 --- {'prn': [".'dZ^st", ".'dZ^st.b.l"], 'hw': 'adjust'}
# 573 --- {'prn': [".'dZ^stm.nt"], 'hw': 'adjustment'}
# 574 --- {'prn': ["'@dZ.t.nt"], 'hw': 'adjutant'}
# 575 --- {'prn': ["'@d,m@n", '#,mEn'], 'hw': 'adman'}
# 576 --- {'prn': ["'@d,m!n"], 'hw': 'admin'}
# 577 --- {'prn': [".d'm!n!st~"], 'hw': 'administer'}
# 578 --- {'prn': [".d,m!n.'stre!S.n"], 'hw': 'administration'}
# 579 --- {'prn': [".d'm!n.,stre!t!v"], 'hw': 'administrative'}
# 580 --- {'prn': [".d'm!n.,stre!t~"], 'hw': 'administrator'}
# 581 --- {'prn': ["'@dmr.b.l", "'@dmr.bli"], 'hw': 'admirable'}
# 582 --- {'prn': ["'@dmr.l"], 'hw': 'admiral'}
# 583 --- {'prn': ["'@dmr.lti"], 'hw': 'Admiralty'}
# 584 --- {'prn': [",@dm.'re!S.n"], 'hw': 'admiration'}
# 585 --- {'prn': [".d'maj~", ".d'ma!r!Nli"], 'hw': 'admire'}
# 586 --- {'prn': [".d'm!s.b.l"], 'hw': 'admissible'}
# 587 --- {'prn': [".d'm!S.n"], 'hw': 'admission'}
# 588 --- {'prn': [".d'm!t", ".d'm!t.dli"], 'hw': 'admit'}
# 589 --- {'prn': [".d'm!tn-s"], 'hw': 'admittance'}
# 590 --- {'prn': ["@d'm!kstS~"], 'hw': 'admixture'}
# 591 --- {'prn': ["@d'mA:n!S", "@d'mA:n!Sm.nt"], 'hw': 'admonish'}
# 592 --- {'prn_brit': 'y', 'prn': [",@dm.'n!S.n", ".d'mA:n.,thori"], 'hw': 'admonition'}
# 593 --- {'prn': [".'du:"], 'hw': 'ado'}
# 594 --- {'prn': [".'doUbi"], 'hw': 'adobe'}
# 595 --- {'prn': [",@d.'lEsn-s"], 'hw': 'adolescence'}
# 596 --- {'prn': [",@d.'lEsn-t"], 'hw': 'adolescent'}
# 597 --- {'prn': [".'dA:pt"], 'hw': 'adopt'}
# 598 --- {'prn': [".'dA:pS.n"], 'hw': 'adoption'}
# 599 --- {'prn': [".'dA:pt!v"], 'hw': 'adoptive'}
# 600 --- {'prn': [".'dor.b.l", ".'dor.bli"], 'hw': 'adorable'}
# 601 --- {'prn': [",@d.'re!S.n"], 'hw': 'adoration'}
# 602 --- {'prn': [".'do~"], 'hw': 'adore'}
# 603 --- {'prn': [".'do~n"], 'hw': 'adorn'}
# 604 --- {'prn': [".'do~nm.nt"], 'hw': 'adornment'}
# 605 --- {'prn': [".'drEn.l.n"], 'hw': 'adrenaline'}
# 606 --- {'prn': [".'dr!ft"], 'hw': 'adrift'}
# 607 --- {'prn': [".'dro!t"], 'hw': 'adroit'}
# 608 --- {'prn': [",@dZ.'le!S.n"], 'hw': 'adulation'}
# 609 --- {'prn': [".'d^lt'@,d^lt"], 'hw': 'adult'}
# 610 --- {'prn': [".'d^lt,hUd"], 'hw': 'adult'}
# 611 --- {'prn': [".'d^lt.,re!t", ".,d^lt.'re!S.n"], 'hw': 'adulterate'}
# 612 --- {'prn': [".'d^lt~r~"], 'hw': 'adulterer'}
# 613 --- {'prn': [".'d^lt.r.s"], 'hw': 'adulteress'}
# 614 --- {'prn': [".'d^lt.ri", ".'d^lt.r.s"], 'hw': 'adultery'}
# 615 --- {'hw': 'adult education'}
# 616 --- {'hw': 'adv'}
# 617 --- {'prn_brit': 'y', 'prn': [".d'v@ns"], 'hw': 'advance'}
# 618 --- {'hw': 'advance'}
# 619 --- {'hw': 'advance'}
# 620 --- {'prn_brit': 'y', 'prn': [".d'v@nst"], 'hw': 'advanced'}
# 621 --- {'hw': 'Advanced level'}
# 622 --- {'prn_brit': 'y', 'prn': [".d'v@nsm.nt"], 'hw': 'advancement'}
# 623 --- {'prn_brit': 'y', 'prn': [".d'v@nt!dZ"], 'hw': 'advantage'}
# 624 --- {'prn_brit': 'y', 'prn': [".d'v@nt!dZd"], 'hw': 'advantaged'}
# 625 --- {'prn': [",@d,v@n'te!dZ.s"], 'hw': 'advantageous'}
# 626 --- {'prn': ["'@d,vEnt"], 'hw': 'advent'}
# 627 --- {'prn': [".d'vEntS~"], 'hw': 'adventure'}
# 628 --- {'prn': [".d'vEntS~r~"], 'hw': 'adventurer'}
# 629 --- {'prn': [".d'vEntS~s.m"], 'hw': 'adventuresome'}
# 630 --- {'hw': 'adventure playground'}
# 631 --- {'prn': [".d'vEntS.,r!z.m", ".d'vEntS.r!st"], 'hw': 'adventurism'}
# 632 --- {'prn': [".d'vEntS.r.s"], 'hw': 'adventurous'}
# 633 --- {'prn': ["'@d,v~b", "@d'v~bij.l"], 'hw': 'adverb'}
# 634 --- {'prn': [",@dv~'serij.l"], 'hw': 'adversarial'}
# 635 --- {'prn_brit': 'y', 'prn': ["'@dv~,seri"], 'hw': 'adversary'}
# 636 --- {'prn': ["@d'v~s'@d,v~s"], 'hw': 'adverse'}
# 637 --- {'prn': ["@d'v~s.ti"], 'hw': 'adversity'}
# 638 --- {'prn': ["'@d,v~t"], 'hw': 'advert'}
# 639 --- {'prn': ["'@dv~,ta!z"], 'hw': 'advertise'}
# 640 --- {'prn_brit': 'y', 'prn': [",@dv~'ta!zm.nt"], 'hw': 'advertisement'}
# 641 --- {'prn': ["'@dv~,ta!z!N"], 'hw': 'advertising'}
# 642 --- {'prn': [".d'va!s"], 'hw': 'advice'}
# 643 --- {'hw': 'advice column'}
# 644 --- {'prn': [".d'va!z.b.#", ".d,va!z.'b!l.ti"], 'hw': 'advisable'}
# 645 --- {'prn': [".d'va!z", ".d'va!z~"], 'hw': 'advise'}
# 646 --- {'prn': [".d'va!z.dli"], 'hw': 'advisedly'}
# 647 --- {'prn': [".d'va!zm.nt"], 'hw': 'advisement'}
# 648 --- {'prn': [".d'va!z.ri"], 'hw': 'advisory'}
# 649 --- {'hw': 'advisory'}
# 650 --- {'prn': ["'@dv.k.si"], 'hw': 'advocacy'}
# 651 --- {'prn': ["'@dv.k.t"], 'hw': 'advocate'}
# is a homograph
# 652 --- {'prn': ["'@dv.,ke!t"], 'hw': 'advocate'}
# is a homograph
# 653 --- {'prn': ["'@dz"], 'hw': 'adze'}
# 654 --- {'prn': ["'@d'hA:k"], 'hw': 'ad hoc'}
# 655 --- {'prn': [",@d,!nf.'na!t.m"], 'hw': 'ad infinitum'}
# 656 --- {'prn': ["@d'nA:zij.m"], 'hw': 'ad nauseam'}
# 657 --- {'prn': ["'i:dZ.s"], 'hw': 'aegis'}
# 658 --- {'hw': 'aeon'}
# 659 --- {'prn': ["'e~,e!t", ",e~'e!S.n"], 'hw': 'aerate'}
# 660 --- {'prn': ["'erij.l"], 'hw': 'aerial'}
# 661 --- {'hw': 'aerial'}
# 662 --- {'prn': ["'eri"], 'hw': 'aerie'}
# 663 --- {'hw': 'aero-'}
# 664 --- {'prn': [",er.'b@t!ks", ",er.'b@t!k"], 'hw': 'aerobatics'}
# 665 --- {'prn': [",e~'oUb!k"], 'hw': 'aerobic'}
# 666 --- {'prn': [",e~'oUb!ks"], 'hw': 'aerobics'}
# 667 --- {'prn': [",eroUda!'n@m!ks", ",eroUda!'n@m!k", ",eroUda!'n@m!kli"], 'hw': 'aerodynamics'}
# 668 --- {'prn': [",er.'nA:t!ks", ",er.'nA:t!k.#"], 'hw': 'aeronautics'}
# 669 --- {'prn': ["'er.,ple!n"], 'hw': 'aeroplane'}
# 670 --- {'prn': ["'er.,sA:l"], 'hw': 'aerosol'}
# 671 --- {'prn': ["'eroU,spe!s"], 'hw': 'aerospace'}
# 672 --- {'prn_brit': 'y', 'prn': ["'Es,thi:t"], 'hw': 'aesthete'}
# 673 --- {'prn_brit': 'y', 'prn': ["Es'thEt!k", "Es'thEt!kli"], 'hw': 'aesthetic'}
# 674 --- {'prn_brit': 'y', 'prn': ["Es'thEt.,s!z.m"], 'hw': 'aesthetic'}
# 675 --- {'prn': [".'fA~"], 'hw': 'afar'}
# 676 --- {'hw': 'AFC'}
# 677 --- {'prn': ["'@f.b.#", ",@f.'b!l.ti", "'@f.bli"], 'hw': 'affable'}
# 678 --- {'prn': [".'fe~"], 'hw': 'affair'}
# 679 --- {'prn': [".'fEkt"], 'hw': 'affect'}
# 680 --- {'prn': [",@,fEk'te!S.n"], 'hw': 'affectation'}
# 681 --- {'prn': [".'fEkt.d"], 'hw': 'affected'}
# 682 --- {'prn': [".'fEkt!N"], 'hw': 'affecting'}
# 683 --- {'prn': [".'fEkS.n"], 'hw': 'affection'}
# 684 --- {'prn': [".'fEkS.n.t"], 'hw': 'affectionate'}
# 685 --- {'prn': [",@f.'de!v.t"], 'hw': 'affidavit'}
# 686 --- {'prn': [".'f!li,e!t"], 'hw': 'affiliate'}
# 687 --- {'prn': [".'f!lij.t"], 'hw': 'affiliate'}
# 688 --- {'prn': [".,f!li'e!S.n"], 'hw': 'affiliation'}
# 689 --- {'prn': [".'f!n.ti"], 'hw': 'affinity'}
# 690 --- {'prn': [".'f~m", ",@f~'me!S.n"], 'hw': 'affirm'}
# 691 --- {'prn': [".'f~m.t!v"], 'hw': 'affirmative'}
# 692 --- {'hw': 'affirmative'}
# 693 --- {'hw': 'affirmative action'}
# 694 --- {'prn': [".'f!ks"], 'hw': 'affix'}
# 695 --- {'prn': ["'@,f!ks"], 'hw': 'affix'}
# 696 --- {'prn': [".'fl!kt"], 'hw': 'afflict'}
# 697 --- {'prn': [".'fl!kS.n"], 'hw': 'affliction'}
# 698 --- {'prn': ["'@fluw.nt", "'@fluw.ns"], 'hw': 'affluent'}
# 699 --- {'prn': [".'fo~d", ".,ford.'b!l.ti", ".'ford.b.l"], 'hw': 'afford'}
# 700 --- {'prn': ["@,for.'ste!S.n"], 'hw': 'afforestation'}
# 701 --- {'prn': [".'fre!"], 'hw': 'affray'}
# 702 --- {'prn': [".'fr^nt"], 'hw': 'affront'}
# 703 --- {'hw': 'affront'}
# 704 --- {'prn': ["'@f,g@n"], 'hw': 'afghan'}
# 705 --- {'prn_brit': 'y', 'prn': ["'@f,g@n", "@f'g@ni"], 'hw': 'Afghan'}
# 706 --- {'hw': 'Afghan hound'}
# 707 --- {'prn': [".,f!Sij.'nA:doU"], 'hw': 'aficionado'}
# 708 --- {'prn': [".'fi:ld"], 'hw': 'afield'}
# 709 --- {'prn': [".'faj~"], 'hw': 'afire'}
# 710 --- {'prn': [".'fle!m"], 'hw': 'aflame'}
# 711 --- {'prn': [".'floUt"], 'hw': 'afloat'}
# 712 --- {'prn': [".'fl^t~"], 'hw': 'aflutter'}
# 713 --- {'prn': [".'fUt"], 'hw': 'afoot'}
# 714 --- {'prn': [".'fo~'mEnS.nd"], 'hw': 'aforementioned'}
# 715 --- {'prn': [".'fo~,sEd"], 'hw': 'aforesaid'}
# 716 --- {'prn': [".'fo~,thA:t"], 'hw': 'aforethought'}
# 717 --- {'prn': [".'faUl.v"], 'hw': 'afoul of'}
# 718 --- {'prn': [".'fre!d"], 'hw': 'afraid'}
# 719 --- {'prn': [".'frES"], 'hw': 'afresh'}
# 720 --- {'prn': [",@fr!k.n.'mer!k.n"], 'hw': 'African-American'}
# 721 --- {'prn': ["'@fr!k.n"], 'hw': 'African'}
# 722 --- {'hw': 'African violet'}
# 723 --- {'prn': [",@fr!'kA:ns"], 'hw': 'Afrikaans'}
# 724 --- {'prn': [",@fr!'kA:n~"], 'hw': 'Afrikaner'}
# 725 --- {'hw': 'Afro-'}
# 726 --- {'prn': [",@frow.'mer.k.n"], 'hw': 'Afro-American'}
# 727 --- {'prn': ["'@froU"], 'hw': 'Afro'}
# 728 --- {'prn_brit': 'y', 'prn': ["'@ft"], 'hw': 'aft'}
# 729 --- {'hw': 'aft'}
# 730 --- {'prn_brit': 'y', 'prn': ["'@ft~,se!lz"], 'hw': 'after-sales'}
# 731 --- {'prn_brit': 'y', 'prn': ["'@ft~,sku:l"], 'hw': 'after-school'}
# 732 --- {'prn_brit': 'y', 'prn': ["'@ft~"], 'hw': 'after'}
# 733 --- {'hw': 'after'}
# 734 --- {'hw': 'after'}
# 735 --- {'hw': 'after'}
# 736 --- {'prn_brit': 'y', 'prn': ["'@ft~,b~th"], 'hw': 'afterbirth'}
# 737 --- {'prn_brit': 'y', 'prn': ["'@ft~,ke~"], 'hw': 'aftercare'}
# 738 --- {'prn_brit': 'y', 'prn': ["'@ft~r!,fEkt"], 'hw': 'aftereffect'}
# 739 --- {'prn_brit': 'y', 'prn': ["'@ft~,gloU"], 'hw': 'afterglow'}
# 740 --- {'prn_brit': 'y', 'prn': ["'@ft~,la!f"], 'hw': 'afterlife'}
# 741 --- {'prn_brit': 'y', 'prn': ["'@ft~,m@th"], 'hw': 'aftermath'}
# 742 --- {'prn_brit': 'y', 'prn': [",@ft~'nu:n"], 'hw': 'afternoon'}
# 743 --- {'prn_brit': 'y', 'prn': [",@ft~'nu:nz"], 'hw': 'afternoons'}
# 744 --- {'prn_brit': 'y', 'prn': ["'@ft~z"], 'hw': 'afters'}
# 745 --- {'prn_brit': 'y', 'prn': ["'@ft~,Se!v"], 'hw': 'aftershave'}
# 746 --- {'prn_brit': 'y', 'prn': ["'@ft~,SA:k"], 'hw': 'aftershock'}
# 747 --- {'prn_brit': 'y', 'prn': ["'@ft~,te!st"], 'hw': 'aftertaste'}
# 748 --- {'prn_brit': 'y', 'prn': ["'@ft~,thA:t"], 'hw': 'afterthought'}
# 749 --- {'prn_brit': 'y', 'prn': ["'@ft~w~d", "'@ft~w~dz"], 'hw': 'afterward'}
# 750 --- {'prn_brit': 'y', 'prn': ["'@ft~,w~d"], 'hw': 'afterword'}
# 751 --- {'prn': [".'gEn"], 'hw': 'again'}
# 752 --- {'prn': [".'gEnst"], 'hw': 'against'}
# 753 --- {'prn': [".'ge!p"], 'hw': 'agape'}
# 754 --- {'prn': ["'@g.t"], 'hw': 'agate'}
# 755 --- {'prn': ["'e!dZ'oUld"], 'hw': 'age-old'}
# 756 --- {'prn': ["'e!dZ"], 'hw': 'age'}
# 757 --- {'hw': 'age'}
# 758 --- {'prn': ["'e!dZ.dn.s"], 'hw': 'aged'}
# 759 --- {'hw': 'ageing'}
# 760 --- {'prn': ["'e!,dZ!z.m", "'e!dZ!st"], 'hw': 'ageism'}
# 761 --- {'prn': ["'e!dZl.s"], 'hw': 'ageless'}
# 762 --- {'prn': ["'e!dZ.nsi"], 'hw': 'agency'}
# 763 --- {'prn': [".'dZEnd."], 'hw': 'agenda'}
# 764 --- {'prn': ["'e!dZ.nt"], 'hw': 'agent'}
# 765 --- {'prn': ["'A:,ZA:nproU,vA:k.'t~", "'A:,ZA:nproU,vA:k.'t~"], 'hw': 'agent provocateur'}
# 766 --- {'hw': 'age of consent'}
# 767 --- {'prn': [".,glA:m.'re!S.n"], 'hw': 'agglomeration'}
# 768 --- {'prn': [".'gr@nd.zm.nt"], 'hw': 'aggrandizement'}
# 769 --- {'prn': ["'@gr.,ve!t"], 'hw': 'aggravate'}
# 770 --- {'hw': 'aggravated'}
# 771 --- {'prn': [",@gr.'ve!S.n"], 'hw': 'aggravation'}
# 772 --- {'prn': ["'@gr!,ge!t", ",@gr!'ge!S.n"], 'hw': 'aggregate'}
# is a homograph
# 773 --- {'prn': ["'@gr!g.t"], 'hw': 'aggregate'}
# is a homograph
# 774 --- {'prn': ["'@gr!g.t"], 'hw': 'aggregate'}
# is a homograph
# 775 --- {'prn': [".'grES.n"], 'hw': 'aggression'}
# 776 --- {'prn': [".'grEs!v"], 'hw': 'aggressive'}
# 777 --- {'prn': [".'grEs~"], 'hw': 'aggressor'}
# 778 --- {'prn': [".'gri:vd"], 'hw': 'aggrieved'}
# 779 --- {'prn': ["'@groU"], 'hw': 'aggro'}
# 780 --- {'prn_brit': 'y', 'prn': [".'g@st"], 'hw': 'aghast'}
# 781 --- {'prn': ["'@dZ.l", ".'dZ!l.ti"], 'hw': 'agile'}
# 782 --- {'hw': 'aging'}
# 783 --- {'hw': 'aging'}
# 784 --- {'prn': ["'@dZ.,te!t", ",@dZ.'te!S.n"], 'hw': 'agitate'}
# 785 --- {'prn': ["'@dZ.,te!t~"], 'hw': 'agitator'}
# 786 --- {'prn': [".'gli:m"], 'hw': 'agleam'}
# 787 --- {'prn': [".'gl!t~"], 'hw': 'aglitter'}
# 788 --- {'prn': [".'gloU"], 'hw': 'aglow'}
# 789 --- {'prn': [",e!,dZi:'Em"], 'hw': 'AGM'}
# 790 --- {'prn': ["@g'nA:st!k", "@g'nA:st.,s!z.m"], 'hw': 'agnostic'}
# 791 --- {'prn': [".'goU"], 'hw': 'ago'}
# 792 --- {'prn': [".'gA:g"], 'hw': 'agog'}
# 793 --- {'prn': ["'@g.,na!z"], 'hw': 'agonize'}
# 794 --- {'hw': 'agonized'}
# 795 --- {'hw': 'agonizing'}
# 796 --- {'prn': ["'@g.ni"], 'hw': 'agony'}
# 797 --- {'hw': 'agony aunt'}
# 798 --- {'hw': 'agony column'}
# 799 --- {'prn': [",@g.r.'foUbij.", ",@g.r.'foUb!k"], 'hw': 'agoraphobia'}
# 800 --- {'prn': [".'grerij.n"], 'hw': 'agrarian'}
# 801 --- {'prn': [".'gri:"], 'hw': 'agree'}
# 802 --- {'prn': [".'gri:j.b.l", ".'gri:j.bli"], 'hw': 'agreeable'}
# 803 --- {'prn': [".'gri:m.nt"], 'hw': 'agreement'}
# 804 --- {'prn': ["'@gr.,b!zn.s"], 'hw': 'agribusiness'}
# 805 --- {'prn': [",@gr!'k^ltS.r.l"], 'hw': 'agricultural'}
# 806 --- {'prn': ["'@gr!,k^ltS~", ",@gr!'k^ltS.r.l!st", ",@gr!'k^ltS.r.l!st"], 'hw': 'agriculture'}
# 807 --- {'prn': [".'grA:n.mi", ".'grAn.m!st"], 'hw': 'agronomy'}
# 808 --- {'prn': [".'graUnd"], 'hw': 'aground'}
# 809 --- {'prn': ["'A:"], 'hw': 'ah'}
# 810 --- {'prn': ["A'hA:"], 'hw': 'aha'}
# 811 --- {'prn': [".'hEd"], 'hw': 'ahead'}
# 812 --- {'hw': 'ahead of'}
# 813 --- {'prn': [".'hEm"], 'hw': 'ahem'}
# 814 --- {'prn': [".'ho!"], 'hw': 'ahoy'}
# 815 --- {'hw': 'AI'}
# 816 --- {'prn': ["'e!d"], 'hw': 'aid'}
# 817 --- {'hw': 'aid'}
# 818 --- {'prn_brit': 'y', 'prn': [",e!dd!'k@mp", ",e!dzd!'k@mp"], 'hw': 'aide-de-camp'}
# 819 --- {'prn': ["'e!d"], 'hw': 'aide'}
# 820 --- {'prn': ["'e!dz"], 'hw': 'AIDS'}
# 821 --- {'prn': ["'e!l"], 'hw': 'ail'}
# 822 --- {'prn': ["'e!l.,rA:n"], 'hw': 'aileron'}
# 823 --- {'prn': ["'e!lm.nt"], 'hw': 'ailment'}
# 824 --- {'prn': ["'e!m"], 'hw': 'aim'}
# 825 --- {'hw': 'aim'}
# 826 --- {'prn': ["'e!ml.s"], 'hw': 'aimless'}
# 827 --- {'prn': ["'e!nt"], 'hw': "ain't"}
# 828 --- {'prn': [",e~k.n'd!S.n!N", ",e~k.n'd!S.nd"], 'hw': 'air-conditioning'}
# 829 --- {'prn': ["'e~'dra!"], 'hw': 'air-dry'}
# 830 --- {'prn': [",e~t.'we~"], 'hw': 'air-to-air'}
# 831 --- {'prn': ["'e~", "'e~l.s"], 'hw': 'air'}
# 832 --- {'hw': 'air'}
# 833 --- {'prn': ["'e~,bo~n"], 'hw': 'airborne'}
# 834 --- {'prn': ["'e~,br^S"], 'hw': 'airbrush'}
# 835 --- {'hw': 'airbrush'}
# 836 --- {'prn': ["'e~,b^s"], 'hw': 'Airbus'}
# 837 --- {'prn_brit': 'y', 'prn': ["'e~,kr@ft"], 'hw': 'aircraft'}
# 838 --- {'hw': 'aircraft carrier'}
# 839 --- {'prn': ["'e~,drA:p", "'e~,drA:p"], 'hw': 'airdrop'}
# 840 --- {'prn': ["'e~,fe~"], 'hw': 'airfare'}
# 841 --- {'prn': ["'e~,fi:ld"], 'hw': 'airfield'}
# 842 --- {'prn': ["'e~,hEd"], 'hw': 'airhead'}
# 843 --- {'prn': ["'er!N"], 'hw': 'airing'}
# 844 --- {'hw': 'airing cupboard'}
# 845 --- {'prn': ["'e~,l!ft"], 'hw': 'airlift'}
# 846 --- {'prn': ["'e~,la!n"], 'hw': 'airline'}
# 847 --- {'prn': ["'e~,la!n~"], 'hw': 'airliner'}
# 848 --- {'prn': ["'e~,me!l"], 'hw': 'airmail'}
# 849 --- {'prn': ["'e~m.n", '#m.n'], 'hw': 'airman'}
# 850 --- {'prn': ["'e~,ple!n"], 'hw': 'airplane'}
# 851 --- {'prn': ["'e~,ple!"], 'hw': 'airplay'}
# 852 --- {'prn': ["'e~,po~t"], 'hw': 'airport'}
# 853 --- {'prn': ["'e~,S!p"], 'hw': 'airship'}
# 854 --- {'prn': ["'e~,s!k"], 'hw': 'airsick'}
# 855 --- {'prn': ["'e~,spe!s"], 'hw': 'airspace'}
# 856 --- {'prn': ["'e~,spi:d"], 'hw': 'airspeed'}
# 857 --- {'prn': ["'e~,str!p"], 'hw': 'airstrip'}
# 858 --- {'prn': ["'e~,ta!t"], 'hw': 'airtight'}
# 859 --- {'prn': ["'e~,ta!m"], 'hw': 'airtime'}
# 860 --- {'prn': ["'e~,we!vz"], 'hw': 'airwaves'}
# 861 --- {'prn': ["'e~,we!"], 'hw': 'airway'}
# 862 --- {'prn': ["'e~,w~THi"], 'hw': 'airworthy'}
# 863 --- {'prn': ["'eri'feri"], 'hw': 'airy-fairy'}
# 864 --- {'prn': ["'eri", "'er.li", "'erin.s"], 'hw': 'airy'}
# 865 --- {'hw': 'air bag'}
# 866 --- {'hw': 'air ball'}
# 867 --- {'hw': 'air base'}
# 868 --- {'hw': 'air bed'}
# 869 --- {'hw': 'air conditioner'}
# 870 --- {'hw': 'air force'}
# 871 --- {'hw': 'air gun'}
# 872 --- {'hw': 'air lock'}
# 873 --- {'hw': 'air mattress'}
# 874 --- {'hw': 'air pocket'}
# 875 --- {'hw': 'air pump'}
# 876 --- {'hw': 'air raid'}
# 877 --- {'hw': 'air rifle'}
# 878 --- {'hw': 'air show'}
# 879 --- {'hw': 'air strike'}
# 880 --- {'hw': 'air traffic control'}
# 881 --- {'hw': 'air traffic controller'}
# 882 --- {'prn': ["'aj.l"], 'hw': 'aisle'}
# 883 --- {'prn': [".'dZA~"], 'hw': 'ajar'}
# 884 --- {'hw': 'AK'}
# 885 --- {'prn': [",e!,ke!'e!"], 'hw': 'aka'}
# 886 --- {'prn': [".'k!mboU"], 'hw': 'akimbo'}
# 887 --- {'prn': [".'k!n"], 'hw': 'akin'}
# 888 --- {'hw': 'AL'}
# 889 --- {'prn_brit': 'y', 'prn': ["'@l.,b@st~"], 'hw': 'alabaster'}
# 890 --- {'prn': [".'l@kr.ti"], 'hw': 'alacrity'}
# 891 --- {'prn': [".'lA~m"], 'hw': 'alarm'}
# 892 --- {'prn': [".'lA~m!Nli"], 'hw': 'alarm'}
# 893 --- {'prn': [".'lA~m!st", ".'lA~,m!z.m"], 'hw': 'alarmist'}
# 894 --- {'hw': 'alarm clock'}
# 895 --- {'prn': [".'l@s"], 'hw': 'alas'}
# 896 --- {'prn': ["'@lb.,trA:s"], 'hw': 'albatross'}
# 897 --- {'prn': ["Al'bi:j.t"], 'hw': 'albeit'}
# 898 --- {'prn_brit': 'y', 'prn': ["@l'ba!noU", "'@lb.,n!z.m"], 'hw': 'albino'}
# 899 --- {'prn': ["'@lb.m"], 'hw': 'album'}
# 900 --- {'prn_brit': 'y', 'prn': ["@l'bju:m.n"], 'hw': 'albumen'}
# 901 --- {'prn': ["'@lk.mi", "'@lk.m!st"], 'hw': 'alchemy'}
# 902 --- {'prn': ["'@lk.,hA:l"], 'hw': 'alcohol'}
# 903 --- {'prn': [",@lk.'hA:l!k", ",@lk.'hA:l!kli"], 'hw': 'alcoholic'}
# 904 --- {'hw': 'alcoholic'}
# 905 --- {'prn': ["'@lk.,hA:,l!z.m"], 'hw': 'alcoholism'}
# 906 --- {'prn': ["'@l,koUv"], 'hw': 'alcove'}
# 907 --- {'prn': ["'A:ld~"], 'hw': 'alder'}
# 908 --- {'prn': ["'A:ld~m.n", '#m.n', ",A:ld~'m@n!k"], 'hw': 'alderman'}
# 909 --- {'prn': ["'e!l"], 'hw': 'ale'}
# 910 --- {'hw': 'aleck'}
# 911 --- {'prn': ["'e!l,haUs"], 'hw': 'alehouse'}
# 912 --- {'prn': [".'l~t"], 'hw': 'alert'}
# 913 --- {'hw': 'alert'}
# 914 --- {'hw': 'alert'}
# 915 --- {'prn': ["@l'f@lf."], 'hw': 'alfalfa'}
# 916 --- {'prn': ["@l'frEskoU"], 'hw': 'alfresco'}
# 917 --- {'prn': ["'@ldZi"], 'hw': 'algae'}
# 918 --- {'prn': ["'@ldZ.br.", ",@ldZ.'brej!k"], 'hw': 'algebra'}
# 919 --- {'prn': ["'@lg.,r!TH.m"], 'hw': 'algorithm'}
# 920 --- {'prn': ["'e!lij.s"], 'hw': 'alias'}
# 921 --- {'hw': 'alias'}
# 922 --- {'prn': ["'@l.,ba!"], 'hw': 'alibi'}
# 923 --- {'prn': ["'e!lij.n"], 'hw': 'alien'}
# 924 --- {'hw': 'alien'}
# 925 --- {'prn': ["'e!lij.,ne!t", ",e!lij.'ne!S.n"], 'hw': 'alienate'}
# 926 --- {'prn': [".'la!t"], 'hw': 'alight'}
# 927 --- {'hw': 'alight'}
# 928 --- {'prn': [".'la!n"], 'hw': 'align'}
# 929 --- {'prn': [".'la!nm.nt"], 'hw': 'alignment'}
# 930 --- {'prn': [".'la!k"], 'hw': 'alike'}
# 931 --- {'hw': 'alike'}
# 932 --- {'prn': [",@l.'mEntri#"], 'hw': 'alimentary canal'}
# 933 --- {'prn_brit': 'y', 'prn': ["'@l.,moUni"], 'hw': 'alimony'}
# 934 --- {'prn': [".'la!v"], 'hw': 'alive'}
# 935 --- {'prn': ["'@lk.,la!"], 'hw': 'alkali'}
# 936 --- {'prn': ["'@lk.,la!n", ",@lk.'l!n.ti"], 'hw': 'alkaline'}
# 937 --- {'hw': 'all-'}
# 938 --- {'prn': [",A:l.'mer.k.n"], 'hw': 'all-American'}
# 939 --- {'prn': [",A:l.'raUnd"], 'hw': 'all-around'}
# 940 --- {'prn': ["'Al'de!"], 'hw': 'all-day'}
# 941 --- {'hw': 'all-encompassing'}
# 942 --- {'prn': ["'A:l,faj~d"], 'hw': 'all-fired'}
# 943 --- {'prn': [",A:l!m'po~tn-t"], 'hw': 'all-important'}
# 944 --- {'prn': [",A:l'!n"], 'hw': 'all-in'}
# 945 --- {'prn': [",A:l!n'klu:s!v"], 'hw': 'all-inclusive'}
# 946 --- {'prn': ["'A:l'na!t"], 'hw': 'all-night'}
# 947 --- {'prn': ["'A:l'na!t~"], 'hw': 'all-nighter'}
# 948 --- {'prn': ["'A:l'aUt"], 'hw': 'all-out'}
# 949 --- {'prn': ["'A:l'paw~f.l-"], 'hw': 'all-powerful'}
# 950 --- {'prn': ["'A:l'p~p.s"], 'hw': 'all-purpose'}
# 951 --- {'prn': ["'A:l'raUnd"], 'hw': 'all-round'}
# 952 --- {'hw': 'all-singing, all-dancing'}
# 953 --- {'prn': ["'A:l,stA~"], 'hw': 'all-star'}
# 954 --- {'hw': 'all-terrain vehicle'}
# 955 --- {'prn': ["'A:l,ta!m"], 'hw': 'all-time'}
# 956 --- {'hw': 'all-wheel drive'}
# 957 --- {'prn': ["'A:l"], 'hw': 'all'}
# 958 --- {'hw': 'all'}
# 959 --- {'hw': 'all'}
# 960 --- {'prn_brit': 'y', 'prn': ["'A:l."], 'hw': 'Allah'}
# 961 --- {'prn': ["@'le!"], 'hw': 'allay'}
# 962 --- {'prn': [",@l!'ge!S.n"], 'hw': 'allegation'}
# 963 --- {'prn': [".'lEdZ"], 'hw': 'allege'}
# 964 --- {'prn': [".'lEdZd", ".'lEdZ.dli"], 'hw': 'alleged'}
# 965 --- {'prn': [".'li:dZ.ns"], 'hw': 'allegiance'}
# 966 --- {'prn_brit': 'y', 'prn': ["'@l.,gori", ",@l.'gor!k.#", ",@l.'gor!kli"], 'hw': 'allegory'}
# 967 --- {'prn': [".'lEgroU"], 'hw': 'allegro'}
# 968 --- {'hw': 'allegro'}
# 969 --- {'prn': [",@l.'lu:j."], 'hw': 'alleluia'}
# 970 --- {'prn': ["'@l.n#"], 'hw': 'Allen wrench'}
# 971 --- {'prn': ["'@l~dZ.n", ",@l~'dZEn!k"], 'hw': 'allergen'}
# 972 --- {'prn': [".'l~dZ!k"], 'hw': 'allergic'}
# 973 --- {'prn': ["'@l~dZ!st"], 'hw': 'allergist'}
# 974 --- {'prn': ["'@l~dZi"], 'hw': 'allergy'}
# 975 --- {'prn': [".'li:vi,e!t", ".,li:vi'e!S.n"], 'hw': 'alleviate'}
# 976 --- {'prn': ["'@li"], 'hw': 'alley'}
# 977 --- {'prn': ["'@li,we!"], 'hw': 'alleyway'}
# 978 --- {'prn': [".'laj.ns"], 'hw': 'alliance'}
# 979 --- {'prn': [".'la!d'@,la!d"], 'hw': 'allied'}
# 980 --- {'prn': ["'@l.,ge!t~"], 'hw': 'alligator'}
# 981 --- {'prn': [".,l!t.'re!S.n", ".'l!t.r.t!v"], 'hw': 'alliteration'}
# 982 --- {'prn': ["'@l.,ke!t", ",@l.'ke!S.n"], 'hw': 'allocate'}
# 983 --- {'prn': [".'lA:t"], 'hw': 'allot'}
# 984 --- {'prn': [".'lA:tm.nt"], 'hw': 'allotment'}
# 985 --- {'prn': ["'A:l,oUv~"], 'hw': 'allover'}
# 986 --- {'prn': [".'laU", ".'law.b.l"], 'hw': 'allow'}
# 987 --- {'prn': [".'law.ns"], 'hw': 'allowance'}
# 988 --- {'prn': ["'@,lo!", ".'lo!"], 'hw': 'alloy'}
# 989 --- {'prn': ["'A:l,spa!s"], 'hw': 'allspice'}
# 990 --- {'prn': [".'lu:d"], 'hw': 'allude'}
# 991 --- {'prn': [".'lu~"], 'hw': 'allure'}
# 992 --- {'prn': [".'lur!N"], 'hw': 'alluring'}
# 993 --- {'prn': [".'lu:Z.n", ".'lu:s!v"], 'hw': 'allusion'}
# 994 --- {'prn': [".'lu:vij.l"], 'hw': 'alluvial'}
# 995 --- {'prn': ["'@,la!"], 'hw': 'ally'}
# 996 --- {'prn': [".'la!"], 'hw': 'ally'}
# 997 --- {'hw': 'all but'}
# 998 --- {'hw': 'all clear'}
# 999 --- {'hw': "All Fools' Day"}
# 1000 --- {'hw': 'all fours'}
# 1001 --- {'hw': 'all get-out'}
# 1002 --- {'hw': 'all right'}
# 1003 --- {'hw': 'all right'}
# 1004 --- {'prn': ["'A:lm.,n@k"], 'hw': 'almanac'}
# 1005 --- {'prn': [",@lm.'mA:t~"], 'hw': 'alma mater'}
# 1006 --- {'prn': ["Al'ma!ti"], 'hw': 'almighty'}
# 1007 --- {'hw': 'Almighty'}
# 1008 --- {'prn': ["'A:m.nd"], 'hw': 'almond'}
# 1009 --- {'prn': ["'@lm.n~"], 'hw': 'almoner'}
# 1010 --- {'prn': ["'A:l,moUst"], 'hw': 'almost'}
# 1011 --- {'prn': ["'A:mz"], 'hw': 'alms'}
# 1012 --- {'prn': ["'A:mz,haUs"], 'hw': 'almshouse'}
# 1013 --- {'prn': ["'@loU"], 'hw': 'aloe'}
# 1014 --- {'prn': ["'@loU'ver."], 'hw': 'aloe vera'}
# ...
# 2184 --- {'prn': ["'b@k,lA:g"], 'hw': 'backlog'}
# 2185 --- {'prn': ["'b@k,p@k"], 'hw': 'backpack'}
# 2186 --- {'hw': 'backpack'}
# 2187 --- {'prn': ["'b@k,pEdl-"], 'hw': 'backpedal'}
# 2188 --- {'prn': ["'b@k,rEst"], 'hw': 'backrest'}
# 2189 --- {'prn': ["'b@k'si:t"], 'hw': 'backseat'}
# 2190 --- {'hw': 'backseat driver'}
# 2191 --- {'prn': ["'b@k,sa!d"], 'hw': 'backside'}
# 2192 --- {'prn': ["'b@k,sl@p!N", "'b@k,sl@p~"], 'hw': 'backslapping'}
# 2193 --- {'prn': ["'b@k,sl@S"], 'hw': 'backslash'}
# 2194 --- {'prn': ["'b@k,sla!d", '#,sl!d', "'b@k,sla!d~"], 'hw': 'backslide'}
# 2195 --- {'prn': ["'b@k,spe!s"], 'hw': 'backspace'}
# 2196 --- {'prn': ["'b@k,sp!n"], 'hw': 'backspin'}
# 2197 --- {'prn': ["'b@k,st@b!N", "'b@k,st@b~"], 'hw': 'backstabbing'}
# 2198 --- {'prn': ["'b@k,ste!dZ"], 'hw': 'backstage'}
# 2199 --- {'prn': ["'b@k,ste~z"], 'hw': 'backstairs'}
# 2200 --- {'prn': ["'b@k,stA:p"], 'hw': 'backstop'}
# 2201 --- {'prn': ["'b@k,stre!t"], 'hw': 'backstraight'}
# 2202 --- {'prn': ["'b@k'stri:t"], 'hw': 'backstreet'}
# 2203 --- {'prn': ["'b@k,strEtS"], 'hw': 'backstretch'}
# 2204 --- {'prn': ["'b@k,stroUk"], 'hw': 'backstroke'}
# 2205 --- {'prn': ["'b@k,sw!N"], 'hw': 'backswing'}
# 2206 --- {'prn': ["'b@k,tr@k"], 'hw': 'backtrack'}
# 2207 --- {'prn': ["'b@k,^p"], 'hw': 'backup'}
# 2208 --- {'prn': ["'b@kw~d,lUk!N"], 'hw': 'backward-looking'}
# 2209 --- {'prn': ["'b@kw~d", "'b@kw~dz"], 'hw': 'backward'}
# 2210 --- {'hw': 'backward'}
# 2211 --- {'prn': ["'b@k,wA:t~"], 'hw': 'backwater'}
# 2212 --- {'prn': ["'b@k'wUdz"], 'hw': 'backwoods'}
# 2213 --- {'prn': [",b@k'wUdzm.n", '#m.n'], 'hw': 'backwoodsman'}
# 2214 --- {'prn': ["'b@k'jA~d"], 'hw': 'backyard'}
# 2215 --- {'hw': 'back and forth'}
# 2216 --- {'hw': 'back burner'}
# 2217 --- {'hw': 'back door'}
# 2218 --- {'hw': 'back matter'}
# 2219 --- {'hw': 'back of beyond'}
# 2220 --- {'hw': 'back order'}
# 2221 --- {'hw': 'back passage'}
# 2222 --- {'hw': 'back talk'}
# 2223 --- {'prn': ["'be!k.n"], 'hw': 'bacon'}
# 2224 --- {'hw': 'bacteria'}
# 2225 --- {'prn': ["b@k,tiri'A:l.dZi", "b@k,tirij.'lA:dZ!k.l", "b@k,tiri'A:l.dZ!st"], 'hw': 'bacteriology'}
# 2226 --- {'prn': ["b@k'tirij.m", "#'tirij.", "b@k'tirij.l"], 'hw': 'bacterium'}
# 2227 --- {'prn': ["'b@d,maUth"], 'hw': 'bad-mouth'}
# 2228 --- {'hw': 'bad-tempered'}
# 2229 --- {'prn': ["'b@d", "'w~s", "'w~st"], 'hw': 'bad'}
# 2230 --- {'hw': 'bad'}
# 2231 --- {'hw': 'bad'}
# 2232 --- {'prn': ["'b@d,@s"], 'hw': 'badass'}
# 2233 --- {'prn': ["'b@di"], 'hw': 'baddie'}
# 2234 --- {'hw': 'bade'}
# 2235 --- {'prn': ["'b@dZ"], 'hw': 'badge'}
# 2236 --- {'prn': ["'b@dZ~"], 'hw': 'badger'}
# 2237 --- {'hw': 'badger'}
# 2238 --- {'prn': ["'b@d,l@ndz"], 'hw': 'badlands'}
# 2239 --- {'prn': ["'b@dli", "'w~s", "'w~st"], 'hw': 'badly'}
# 2240 --- {'prn': ["'b@d,m!tn-"], 'hw': 'badminton'}
# 2241 --- {'hw': 'bad blood'}
# 2242 --- {'hw': 'bad boy'}
# 2243 --- {'hw': 'bad faith'}
# 2244 --- {'hw': 'bad language'}
# 2245 --- {'hw': 'bad news'}
# 2246 --- {'prn': ["'b@f.l", "'b@f.lm.nt", "'b@fl!Nli"], 'hw': 'baffle'}
# 2247 --- {'hw': 'baffle'}
# 2248 --- {'prn': ["'b@g"], 'hw': 'bag'}
# 2249 --- {'hw': 'bag'}
# 2250 --- {'prn': ["'be!g.l"], 'hw': 'bagel'}
# 2251 --- {'prn': ["'b@g,fUl"], 'hw': 'bagful'}
# 2252 --- {'prn': ["'b@g!dZ"], 'hw': 'baggage'}
# 2253 --- {'prn': ["'b@gi"], 'hw': 'baggy'}
# 2254 --- {'prn': ["'b@g,pa!p"], 'hw': 'bagpipe'}
# 2255 --- {'prn': ["b@'gEt"], 'hw': 'baguette'}
# 2256 --- {'hw': 'bag lady'}
# 2257 --- {'hw': 'bag lunch'}
# 2258 --- {'hw': 'bag of bones'}
# 2259 --- {'prn': ["'bA:"], 'hw': 'bah'}
# 2260 --- {'prn': ["'be!l"], 'hw': 'bail'}
# 2261 --- {'hw': 'bail'}
# 2262 --- {'hw': 'bail'}
# 2263 --- {'prn': ["'be!l.f"], 'hw': 'bailiff'}
# 2264 --- {'prn': ["'be!l,aUt"], 'hw': 'bailout'}
# 2265 --- {'prn': ["'be~n"], 'hw': 'bairn'}
# 2266 --- {'prn': ["'be!t"], 'hw': 'bait'}
# 2267 --- {'hw': 'bait'}
# 2268 --- {'hw': 'bait and switch'}
# 2269 --- {'prn': ["'be!k"], 'hw': 'bake'}
# 2270 --- {'hw': 'baked beans'}
# 2271 --- {'hw': "baker's dozen"}
# 2272 --- {'prn': ["'be!k~"], 'hw': 'baker'}
# 2273 --- {'prn': ["'be!k.ri"], 'hw': 'bakery'}
# 2274 --- {'hw': 'bake sale'}
# 2275 --- {'hw': 'baking powder'}
# 2276 --- {'hw': 'baking sheet'}
# 2277 --- {'hw': 'baking soda'}
# 2278 --- {'hw': 'baking tray'}
# 2279 --- {'prn': [",b@l.'klA:v."], 'hw': 'balaclava'}
# 2280 --- {'prn': ["'b@l.ns"], 'hw': 'balance'}
# 2281 --- {'hw': 'balance'}
# 2282 --- {'prn': ["'b@l.nst"], 'hw': 'balanced'}
# 2283 --- {'hw': 'balance beam'}
# 2284 --- {'hw': 'balance of payments'}
# 2285 --- {'hw': 'balance of power'}
# 2286 --- {'hw': 'balance of trade'}
# 2287 --- {'hw': 'balance sheet'}
# 2288 --- {'prn': ["'b@lk.ni"], 'hw': 'balcony'}
# 2289 --- {'prn': ["'bA:ld'fe!st"], 'hw': 'bald-faced'}
# 2290 --- {'prn': ["'bA:ld"], 'hw': 'bald'}
# 2291 --- {'prn': ["'bA:ld~,d@S"], 'hw': 'balderdash'}
# 2292 --- {'prn': ["'bA:ld!N"], 'hw': 'balding'}
# 2293 --- {'hw': 'bald eagle'}
# 2294 --- {'prn': ["'be!l"], 'hw': 'bale'}
# 2295 --- {'hw': 'bale'}
# 2296 --- {'hw': 'bale'}
# 2297 --- {'prn': ["'be!lf.l"], 'hw': 'baleful'}
# 2298 --- {'prn': ["'bA:k"], 'hw': 'balk'}
# 2299 --- {'hw': 'balk'}
# 2300 --- {'prn': ["'bA:ki"], 'hw': 'balky'}
# 2301 --- {'prn': ["'bA:l"], 'hw': 'ball'}
# 2302 --- {'hw': 'ball'}
# 2303 --- {'hw': 'ball'}
# 2304 --- {'prn': ["'b@l.d"], 'hw': 'ballad'}
# 2305 --- {'prn': ["'b@l.st"], 'hw': 'ballast'}
# 2306 --- {'prn': [",b@l.'ri:n."], 'hw': 'ballerina'}
# 2307 --- {'prn': ["b@'le!'b@,le!", "b@'lEdd!k"], 'hw': 'ballet'}
# 2308 --- {'prn': ["b.'l!st!k"], 'hw': 'ballistic'}
# 2309 --- {'prn': ["b.'l!st!ks"], 'hw': 'ballistics'}
# 2310 --- {'hw': 'ballistic missile'}
# 2311 --- {'prn': ["b.'lu:n"], 'hw': 'balloon'}
# 2312 --- {'hw': 'balloon'}
# 2313 --- {'prn': ["b.'lu:n!N", "b.'lu:n!st"], 'hw': 'ballooning'}
# 2314 --- {'hw': 'balloon payment'}
# 2315 --- {'prn': ["'b@l.t"], 'hw': 'ballot'}
# 2316 --- {'hw': 'ballot'}
# 2317 --- {'hw': 'balloting'}
# 2318 --- {'hw': 'ballot box'}
# 2319 --- {'prn': ["'bA:l,pA~k"], 'hw': 'ballpark'}
# 2320 --- {'hw': 'ballpark'}
# 2321 --- {'prn': ["'bA:l,plej~"], 'hw': 'ballplayer'}
# 2322 --- {'prn': ["'bA:l,po!nt#"], 'hw': 'ballpoint pen'}
# 2323 --- {'prn': ["'bA:l,ru:m"], 'hw': 'ballroom'}
# 2324 --- {'hw': 'ballroom dancing'}
# 2325 --- {'prn': ["'bA:lz,^p"], 'hw': 'balls-up'}
# 2326 --- {'prn': ["'bA:lz"], 'hw': 'balls'}
# 2327 --- {'prn': ["'bA:lzi"], 'hw': 'ballsy'}
# 2328 --- {'prn': ["'b@li,hu:"], 'hw': 'ballyhoo'}
# 2329 --- {'hw': 'ball and chain'}
# 2330 --- {'hw': 'ball bearing'}
# 2331 --- {'hw': 'ball boy'}
# 2332 --- {'hw': 'ball game'}
# 2333 --- {'hw': 'ball girl'}
# 2334 --- {'hw': 'ball of fire'}
# 2335 --- {'hw': 'ball of wax'}
# 2336 --- {'prn': ["'bA:m"], 'hw': 'balm'}
# 2337 --- {'prn': ["'bA:mi"], 'hw': 'balmy'}
# 2338 --- {'prn': ["b.'loUni"], 'hw': 'baloney'}
# 2339 --- {'prn': ["'bA:ls."], 'hw': 'balsa'}
# 2340 --- {'prn': ["'bA:ls.m"], 'hw': 'balsam'}
# 2341 --- {'prn': ["bAl's@m!k#"], 'hw': 'balsamic vinegar'}
# 2342 --- {'hw': 'balsam fir'}
# 2343 --- {'prn': ["'b@l.st~"], 'hw': 'baluster'}
# 2344 --- {'prn': ["'b@l.,stre!d"], 'hw': 'balustrade'}
# 2345 --- {'prn': ["'b@m"], 'hw': 'bam'}
# 2346 --- {'prn': ["b@m'bu:"], 'hw': 'bamboo'}
# 2347 --- {'prn': ["b@m'bu:z.l"], 'hw': 'bamboozle'}
# 2348 --- {'prn': ["'b@n"], 'hw': 'ban'}
# 2349 --- {'hw': 'ban'}
# 2350 --- {'prn': ["b.'n@lb.'nA:l'be!n.l"], 'hw': 'banal'}
# 2351 --- {'prn': ["b.'n@l.ti"], 'hw': 'banality'}
# 2352 --- {'prn_brit': 'y', 'prn': ["b.'n@n."], 'hw': 'banana'}
# 2353 --- {'prn_brit': 'y', 'prn': ["b.'n@n.z"], 'hw': 'bananas'}
# 2354 --- {'hw': 'banana republic'}
# 2355 --- {'hw': 'banana split'}
# 2356 --- {'prn': ["'b@nd'e!d"], 'hw': 'Band-Aid'}
# 2357 --- {'hw': 'Band-Aid'}
# 2358 --- {'prn': ["'b@nd"], 'hw': 'band'}
# 2359 --- {'hw': 'band'}
# 2360 --- {'prn': ["'b@nd!dZ"], 'hw': 'bandage'}
# 2361 --- {'hw': 'bandage'}
# 2362 --- {'prn': ["b@n'd@n."], 'hw': 'bandanna'}
# 2363 --- {'prn': ["'b@nd.d"], 'hw': 'banded'}
# 2364 --- {'prn': ["'b@nd.t", "'b@nd.tri"], 'hw': 'bandit'}
# 2365 --- {'prn': ["'b@nd,li:d~"], 'hw': 'bandleader'}
# 2366 --- {'prn_brit': 'y', 'prn': ["'b@nd,m@st~"], 'hw': 'bandmaster'}
# 2367 --- {'prn': [",b@nd.'li~"], 'hw': 'bandolier'}
# 2368 --- {'prn': ["'b@ndzm.n"], 'hw': 'bandsman'}
# 2369 --- {'prn': ["'b@nd,st@nd"], 'hw': 'bandstand'}
# 2370 --- {'prn': ["'b@nd,w@g.n"], 'hw': 'bandwagon'}
# 2371 --- {'prn': ["'b@nd,w!dth"], 'hw': 'bandwidth'}
# 2372 --- {'prn': ["'b@ndi"], 'hw': 'bandy'}
# 2373 --- {'hw': 'band saw'}
# 2374 --- {'prn': ["'be!n"], 'hw': 'bane'}
# 2375 --- {'prn': ["'be!nf.l"], 'hw': 'baneful'}
# 2376 --- {'prn': ["'b@N,^p"], 'hw': 'bang-up'}
# 2377 --- {'prn': ["'b@N"], 'hw': 'bang'}
# 2378 --- {'hw': 'bang'}
# 2379 --- {'hw': 'bang'}
# 2380 --- {'prn': ["'b@N~"], 'hw': 'banger'}
# 2381 --- {'prn': ["'b@Ng.l"], 'hw': 'bangle'}
# 2382 --- {'prn': ["'b@Nz"], 'hw': 'bangs'}
# 2383 --- {'prn': ["'b@n!S", "'b@n!Sm.nt"], 'hw': 'banish'}
# 2384 --- {'prn': ["'b@n.st~"], 'hw': 'banister'}
# 2385 --- {'prn': ["'b@ndZoU"], 'hw': 'banjo'}
# 2386 --- {'prn': ["'b@Nk"], 'hw': 'bank'}
# 2387 --- {'hw': 'bank'}
# 2388 --- {'hw': 'bank'}
# 2389 --- {'hw': 'bank'}
# 2390 --- {'hw': 'bank'}
# 2391 --- {'prn': ["'b@Nk.b.l"], 'hw': 'bankable'}
# 2392 --- {'prn': ["'b@Nk,bUk"], 'hw': 'bankbook'}
# 2393 --- {'hw': "banker's card"}
# 2394 --- {'prn': ["'b@Nk~"], 'hw': 'banker'}
# 2395 --- {'hw': 'banking'}
# 2396 --- {'hw': 'banknote'}
# 2397 --- {'prn': ["'b@Nk,roUl"], 'hw': 'bankroll'}
# 2398 --- {'hw': 'bankroll'}
# 2399 --- {'prn': ["'b@Nk,r^pt"], 'hw': 'bankrupt'}
# 2400 --- {'hw': 'bankrupt'}
# 2401 --- {'hw': 'bankrupt'}
# 2402 --- {'prn': ["'b@Nk,r^ptsi"], 'hw': 'bankruptcy'}
# 2403 --- {'prn': ["'b@Nk,kA~d"], 'hw': 'bank card'}
# 2404 --- {'hw': 'bank draft'}
# 2405 --- {'hw': 'bank holiday'}
# 2406 --- {'hw': 'bank rate'}
# 2407 --- {'prn': ["'b@n~"], 'hw': 'banner'}
# 2408 --- {'hw': 'banner'}
# 2409 --- {'hw': 'bannister'}
# 2410 --- {'prn': ["'b@nz"], 'hw': 'banns'}
# 2411 --- {'prn': ["'b@Nkw.t", "'b@Nkw.t!N"], 'hw': 'banquet'}
# 2412 --- {'prn': ["'b@n,Si:"], 'hw': 'banshee'}
# 2413 --- {'prn': ["'b@nt.m"], 'hw': 'bantam'}
# 2414 --- {'prn': ["'b@nt.m,we!t"], 'hw': 'bantamweight'}
# 2415 --- {'prn': ["'b@nt~"], 'hw': 'banter'}
# 2416 --- {'prn': ["'b@nj.n"], 'hw': 'banyan'}
# 2417 --- {'prn': ["'b@p"], 'hw': 'bap'}
# 2418 --- {'prn': ["'b@p,t!z.m", "b@p'th!zm.#"], 'hw': 'baptism'}
# 2419 --- {'prn': ["'b@p,t!st"], 'hw': 'Baptist'}
# 2420 --- {'prn': ["'b@p,ta!zb@p'ta!z"], 'hw': 'baptize'}
# 2421 --- {'prn': ["'bA~"], 'hw': 'bar'}
# 2422 --- {'hw': 'bar'}
# 2423 --- {'hw': 'bar'}
# 2424 --- {'prn': ["'bA~b"], 'hw': 'barb'}
# 2425 --- {'prn': ["bA~'berij.n"], 'hw': 'barbarian'}
# 2426 --- {'prn': ["bA~'ber!k", "bA~'ber!kli"], 'hw': 'barbaric'}
# 2427 --- {'prn': ["'bA~b.,r!z.m"], 'hw': 'barbarism'}
# 2428 --- {'prn': ["bA~'ber.ti"], 'hw': 'barbarity'}
# 2429 --- {'prn': ["'bA~b.r.s"], 'hw': 'barbarous'}
# 2430 --- {'prn': ["'bA~b!,kju:"], 'hw': 'barbecue'}
# 2431 --- {'hw': 'barbecue'}
# 2432 --- {'prn': ["'bA~bd"], 'hw': 'barbed'}
# 2433 --- {'hw': 'barbed wire'}
# 2434 --- {'prn': ["'bA~,bEl"], 'hw': 'barbell'}
# 2435 --- {'prn': ["'bA~b~"], 'hw': 'barber'}
# 2436 --- {'prn': ["'bA~b~,SA:p"], 'hw': 'barbershop'}
# 2437 --- {'hw': 'barbershop quartet'}
# 2438 --- {'prn': ["'bA~bi"], 'hw': 'barbie'}
# 2439 --- {'prn': ["bA~'b!tS.r.t"], 'hw': 'barbiturate'}
# 2440 --- {'prn': ["'bA~b'waj~"], 'hw': 'barbwire'}
# 2441 --- {'prn': ["'bA~d"], 'hw': 'bard'}
# 2442 --- {'hw': 'bare-bones'}
# 2443 --- {'prn': ["'be~,h@nd.d"], 'hw': 'bare-handed'}
# 2444 --- {'prn': ["'be~'n^k.l", "'be~'n^k.ld", "'be~'n^k.lz"], 'hw': 'bare-knuckle'}
# 2445 --- {'prn': ["'be~"], 'hw': 'bare'}
# 2446 --- {'hw': 'bare'}
# 2447 --- {'prn': ["'be~,b@k"], 'hw': 'bareback'}
# 2448 --- {'prn': ["'be~'fe!st"], 'hw': 'barefaced'}
# 2449 --- {'prn': ["'be~,fUt", "'be~,fUt.d"], 'hw': 'barefoot'}
# 2450 --- {'prn': ["'be~'hEd.d"], 'hw': 'bareheaded'}
# 2451 --- {'prn': ["'be~li"], 'hw': 'barely'}
# 2452 --- {'hw': 'bare bones'}
# 2453 --- {'prn': ["'bA~f"], 'hw': 'barf'}
# 2454 --- {'prn': ["'bA~,fla!"], 'hw': 'barfly'}
# 2455 --- {'prn': ["'bA~g.n'be!sm.nt"], 'hw': 'bargain-basement'}
# 2456 --- {'prn': ["'bA~g.n"], 'hw': 'bargain'}
# 2457 --- {'hw': 'bargain'}
# 2458 --- {'hw': 'bargaining chip'}
# 2459 --- {'hw': 'bargain basement'}
# 2460 --- {'prn': ["'bA~dZ"], 'hw': 'barge'}
# 2461 --- {'hw': 'barge'}
# 2462 --- {'prn': ["'bA~dZ,poUl"], 'hw': 'bargepole'}
# 2463 --- {'prn': ["'bA~,hAp"], 'hw': 'barhop'}
# 2464 --- {'prn': ["b.'ri:st."], 'hw': 'barista'}
# 2465 --- {'prn': ["'ber.,toUn"], 'hw': 'baritone'}
# 2466 --- {'hw': 'baritone'}
# 2467 --- {'prn': ["'berij.m"], 'hw': 'barium'}
# 2468 --- {'prn': ["'bA~k"], 'hw': 'bark'}
# 2469 --- {'hw': 'bark'}
# 2470 --- {'hw': 'bark'}
# 2471 --- {'prn': ["'bA~k"], 'hw': 'bark'}
# 2472 --- {'prn': ["'bA~,ki:p", "'bA~,ki:p~"], 'hw': 'barkeep'}
# 2473 --- {'prn': ["'bA~k~"], 'hw': 'barker'}
# 2474 --- {'hw': 'barking'}
# 2475 --- {'hw': 'barking mad'}
# 2476 --- {'prn': ["'bA~li"], 'hw': 'barley'}
# 2477 --- {'hw': 'barley sugar'}
# 2478 --- {'hw': 'barley wine'}
# 2479 --- {'prn': ["'bA~,me!d"], 'hw': 'barmaid'}
# 2480 --- {'prn': ["'bA~m.n", '#m.n'], 'hw': 'barman'}
# 2481 --- {'prn': ["'bA~mi"], 'hw': 'barmy'}
# 2482 --- {'prn': ["'bA~n"], 'hw': 'barn'}
# 2483 --- {'prn': ["'bA~n!k.l", "'bA~n!k.#d"], 'hw': 'barnacle'}
# 2484 --- {'prn': ["'bA~,sto~m"], 'hw': 'barnstorm'}
# 2485 --- {'hw': 'barnstorming'}
# 2486 --- {'prn': ["'bA~n,jA~d"], 'hw': 'barnyard'}
# 2487 --- {'hw': 'barnyard'}
# 2488 --- {'hw': 'barn burner'}
# 2489 --- {'hw': 'barn dance'}
# 2490 --- {'hw': 'barn owl'}
# 2491 --- {'prn': ["b.'rA:m.t~", ",ber.'mEtr!k"], 'hw': 'barometer'}
# 2492 --- {'prn': ["'ber.n"], 'hw': 'baron'}
# 2493 --- {'prn': ["'ber.n.s"], 'hw': 'baroness'}
# 2494 --- {'prn': ["'ber.n.t", "'ber.n.tsi"], 'hw': 'baronet'}
# 2495 --- {'prn': ["b.'roUnij.l"], 'hw': 'baronial'}
# 2496 --- {'prn': ["'ber.ni"], 'hw': 'barony'}
# 2497 --- {'prn': ["b.'roUk"], 'hw': 'baroque'}
# 2498 --- {'hw': 'barque'}
# 2499 --- {'prn': ["'ber.k"], 'hw': 'barrack'}
# 2500 --- {'prn': ["'ber.ks"], 'hw': 'barracks'}
# 2501 --- {'prn': [",ber.'ku:d."], 'hw': 'barracuda'}
# 2502 --- {'prn_brit': 'y', 'prn': ["b.'rA:Z"], 'hw': 'barrage'}
# 2503 --- {'hw': 'barrage'}
# 2504 --- {'prn': ["'bAr!dZ"], 'hw': 'barrage'}
# 2505 --- {'prn': ["'bA~d"], 'hw': 'barred'}
# 2506 --- {'prn': ["'ber.l,tSEst.d"], 'hw': 'barrel-chested'}
# 2507 --- {'prn': ["'ber.l", "'ber.ld"], 'hw': 'barrel'}
# 2508 --- {'hw': 'barrel'}
# 2509 --- {'hw': 'barrel organ'}
# 2510 --- {'prn': ["'ber.n"], 'hw': 'barren'}
# 2511 --- {'prn': ["bA'rEt"], 'hw': 'barrette'}
# 2512 --- {'prn': ["'ber.,ke!d"], 'hw': 'barricade'}
# 2513 --- {'hw': 'barricade'}
# 2514 --- {'prn': ["'berij~"], 'hw': 'barrier'}
# 2515 --- {'hw': 'barrier island'}
# 2516 --- {'hw': 'barrier reef'}
# 2517 --- {'prn': ["'bAr!N"], 'hw': 'barring'}
# 2518 --- {'prn': ["'bArijoU"], 'hw': 'barrio'}
# 2519 --- {'prn': ["'ber.st~"], 'hw': 'barrister'}
# 2520 --- {'prn': ["'bA~,ru:m"], 'hw': 'barroom'}
# 2521 --- {'prn': ["'beroU"], 'hw': 'barrow'}
# 2522 --- {'prn': ["'bA~,tEnd~", "'bA~,tEnd"], 'hw': 'bartender'}
# 2523 --- {'prn': ["'bA~t~"], 'hw': 'barter'}
# 2524 --- {'hw': 'barter'}
# 2525 --- {'hw': 'bar chart'}
# 2526 --- {'hw': 'bar code'}
# 2527 --- {'hw': 'bar graph'}
# 2528 --- {'prn': ["bA~'m!tsv."], 'hw': 'bar mitzvah'}
# 2529 --- {'prn': [",bA:r!'li:f"], 'hw': 'bas-relief'}
# 2530 --- {'prn': ["b.'sA:lt", "b.'sA:lt!k"], 'hw': 'basalt'}
# 2531 --- {'prn': ["'be!s"], 'hw': 'base'}
# 2532 --- {'hw': 'base'}
# 2533 --- {'hw': 'base'}
# 2534 --- {'prn': ["'be!s,bA:l"], 'hw': 'baseball'}
# 2535 --- {'hw': 'baseball cap'}
# 2536 --- {'prn': ["'be!s,bo~d"], 'hw': 'baseboard'}
# 2537 --- {'hw': 'based'}
# 2538 --- {'prn': ["'be!sl.s"], 'hw': 'baseless'}
# 2539 --- {'prn': ["'be!s,la!n"], 'hw': 'baseline'}
# 2540 --- {'hw': 'baseman'}
# 2541 --- {'prn': ["'be!sm.nt"], 'hw': 'basement'}
# 2542 --- {'hw': 'bases'}
# 2543 --- {'hw': 'base hit'}
# 2544 --- {'hw': 'base on balls'}
# 2545 --- {'hw': 'base path'}
# 2546 --- {'hw': 'base pay'}
# 2547 --- {'hw': 'base runner'}
# 2548 --- {'prn': ["'b@S"], 'hw': 'bash'}
# 2549 --- {'hw': 'bash'}
# 2550 --- {'prn': ["'b@Sf.l"], 'hw': 'bashful'}
# 2551 --- {'prn': ["'be!s!k"], 'hw': 'basic'}
# 2552 --- {'hw': 'basic'}
# 2553 --- {'prn': ["'be!s!k"], 'hw': 'BASIC'}
# 2554 --- {'prn': ["'be!s!kli"], 'hw': 'basically'}
# 2555 --- {'hw': 'basic training'}
# 2556 --- {'prn': ["'b@z.l'be!z.l"], 'hw': 'basil'}
# 2557 --- {'prn': ["b.'s!l!k."], 'hw': 'basilica'}
# 2558 --- {'prn': ["'b@s.,l!sk"], 'hw': 'basilisk'}
# 2559

# %%
# output mwl39195hw.txt  (having duplicates because of homographs)
# and explore 39195 hw entries
# 2015-12-01

import pymongo
from pymongo import MongoClient

# codecs if for read and write files with unicode, encoding 'utf-8'
import codecs
import string

#connect to MongoDB
client = MongoClient('localhost', 27017)
db = client.dpdb  # databas: dpdb
geweiDict = db.geweiDict201511 # collection (table): geweiDict201511
#geweiDict = db.geweiDictTest

fhw = codecs.open('E:\\1Now\\taglist\\mwl39195hwraw.txt', 'w', 'utf-8')
    
results = geweiDict.find({}, {"_id":0, "hw":1}) #.limit(1000)


totalhw = 0 # total number of head words
for result in results:    
    word = result.get("hw")    
    if word:
        #print word
        fhw.write(word + '\n')
        totalhw += 1
    else:
        print "no head word"
        continue

fhw.close()
print "total head words: ", totalhw


# sort out by head words and output
# with homographs, 39195 head words have duplicates; unique number is 34398

# create mwl39195hw.txt
with codecs.open('E:\\1Now\\taglist\\mwl39195hwraw.txt', 'r', 'utf-8') as f:
    lines = f.read().splitlines()
lines = sorted(lines)
print 'hw unique number: ', len(set(lines))

fd = codecs.open('E:\\1Now\\taglist\\mwl39195hw.txt', 'w', 'utf-8')
cnt = 0
for line in lines:
    fd.write(line + '\n')
    cnt += 1
fd.close()
print cnt



# explore 39195 hws
with codecs.open('E:\\1Now\\taglist\\mwl39195hw.txt', 'r', 'utf-8') as f:
    words = f.read().splitlines()
    f.close()
print 'number of hws with homographs: ', len(words)
print 'number of unique hws: ', len(set(words))

# wordsC = [x.capitalize() for x in words]
wordsC = []
for word in words:
    # only capitalize words beginning with a lowercase letter. no need for 'Feburary'
    # Don't capitalize words like 'AWOL' -- Awol is not a word!
    if word[0] in string.lowercase[0:26]:
        wordsC.append(word.capitalize())
        cnt += 1
    
print 'number of words capitalized: ', len(wordsC)

# put words and wordsC together and get unique
# wordsTotal = sorted(set(words + wordsC))
# fd = codecs.open('E:\\1Now\\taglist\\mwl39195hwCap.txt', 'w', 'utf-8')
# for x in wordsTotal:
#     fd.write(x + '\n')
# fd.close()
# print len(wordsTotal)

# %%
# output mwl39195sum.txt  (having duplicate hws)
# hw entries and their summary (subhw, prn, idpvs, tags)
# 2015-11-27 2015-12-01

import pymongo
from pymongo import MongoClient

# codecs if for read and write files with unicode, encoding 'utf-8'
import codecs

#connect to MongoDB
client = MongoClient('localhost', 27017)
db = client.dpdb  # databas: dpdb
geweiDict = db.geweiDict201511 # collection (table): geweiDict201511
#geweiDict = db.geweiDictTest

fdict = codecs.open('E:\\1Now\\taglist\\mwl39195sumraw.txt', 'w', 'utf-8')
    
results = geweiDict.find({}, {"_id":0, "hw":1, "subhw":1, "prn":1, "idpvs":1, "tag":1}) #.limit(1000)


totalhw = 0 # total number of head words
for result in results:    
    word = result.get("hw")    
    if word:
        #print word
        fdict.write(word)
        totalhw += 1
    else:
        print "no head word"
        continue

    # get items of result
    prns = result.get("prn")
    subhws = result.get("subhw")
    idpvs = result.get("idpvs")  
    tags = result.get('tag')
    
    if subhws:
        cnt = 1
        for subhw in subhws:
            if cnt == 1: fdict.write(' (' + subhw)                
            else: fdict.write(' ' + subhw)
            cnt += 1        
        fdict.write(')')
    
    if prns:
        cnt = 1
        for prn in prns:                 
            fdict.write(' /' + prn + '/')
            cnt += 1

    if idpvs:
        cnt = 1
        for idpv in idpvs:
            if cnt == 1: fdict.write('  [' + idpv)
            else: fdict.write(', ' + idpv)
            cnt += 1
        fdict.write(']')
            
    if tags:
        cnt = 1
        for tag in tags:
            if tag == 'mwl': continue
            if cnt == 1: fdict.write('  {' + tag)
            else: fdict.write(' ' + tag)
            cnt += 1
        fdict.write('}')

    fdict.write('\n')    

fdict.close()
print "total head words: ", totalhw


# sort out and create mwl39195sum.txt
with codecs.open('E:\\1Now\\taglist\\mwl39195sumraw.txt', 'r', 'utf-8') as f:
    lines = f.read().splitlines()
lines = sorted(lines)
print 'hw summary unique number: ', len(set(lines))

fd = codecs.open('E:\\1Now\\taglist\\mwl39195sum.txt', 'w', 'utf-8')
cnt = 0
for line in lines:
    fd.write(line + '\n')
    cnt += 1
fd.close()
print cnt
# Out:
# total head words:  39195
# hw summary unique number:  39044
# 39195

# %%
ta = "a, b, c"
tb = 'dd'
print ta.split(',')[0]
# Out:
# a

# %%
with open('core3000\\topic.txt', 'r') as f:
    lines = f.read().splitlines()
print lines
# Out:
# ['acaWriting.txt', 'airTravel.txt', 'bodyPart.txt', 'campus.txt', 'economics.txt', 'emotion.txt', 'employment.txt', 'environment.txt', 'family.txt', 'health.txt', 'job.txt', 'legal.txt', 'list.txt', 'nonCount.txt', 'personality.txt', 'sport.txt', 'timeAdv.txt', 'timePeriod.txt', 'weather.txt']

# %%
import codecs

tfiles = ['acaWriting.txt', 'airTravel.txt', 'bodyPart.txt', 'campus.txt', 'economics.txt', 'emotion.txt', 
          'employment.txt', 'environment.txt', 'family.txt', 'health.txt', 'job.txt', 'legal.txt', 
          'nonCount.txt', 'personality.txt', 'sport.txt', 'timeAdv.txt', 'timePeriod.txt', 'weather.txt']
topics = []
cnt = 0
for tfile in tfiles:
    topic = {}
    with codecs.open('core3000\\' + tfile, 'r', 'utf-8') as f:
        twords = f.read().splitlines()
        cnt += len(twords)
        f.close()
    topic['words'] = twords
    topic['topic'] = tfile.split('.')[0]
    topics.append(topic)
#print topics    
print cnt
# Out:
# 914

# %%
import codecs

fcore = codecs.open('core3000\\core3140.txt', 'w', 'utf-8')
with codecs.open('core3000\\core3000raw20151123.txt', 'r', 'utf-8') as f:
    lines = f.read().splitlines()

cnt = 0    
uCore = set()

for line in lines:    
    uCore.add(line.split('\t')[0])
uCoreSorted = sorted(uCore)    
for word in uCoreSorted:
    cnt += 1
    fcore.write(word+'\n')
    #print cnt, ': ', word
fcore.close()

# %%
print(soup.img.decompose())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-a6d700773372> in <module>()
# ----> 1 print(soup.img.decompose())
#
# AttributeError: 'NoneType' object has no attribute 'decompose'

# %%
dpdict.find({"label":"mathematics"}).count()
# Out:
# 64

# %%
dpdict.find({"label":"slang"}).count()
# Out:
# 29

# %%
dpdict.find({"label":"offensive"}).count()
# Out:
# 33

# %%
dpdict.find({"label":"chiefly US"}).count()
# Out:
# 807

# %%
dpdict.find({"label":"Brit"}).count()
# Out:
# 2615

# %%
db.dpdict.find({"label":"US"}).count()
# Out:
# 2027

# %%
db.dpdict.find({cp: {$exists: true}}).count()
# Out:
#   File "<ipython-input-208-11f5d97b9c3b>", line 1
#     db.dpdict.find({cp: {$exists: true}}).count()
#                          ^
# SyntaxError: invalid syntax

# %%
dpdict.find_one({'hw': u'doppelg\xe4nger'})
# Out:
# {u'_id': ObjectId('537e93cd8707ee3128063ada'),
#  u'alles': [u'I saw your doppelg\xe4nger [=(more commonly) double] yesterday.',
#   u'In the story, the character is haunted by a doppelg\xe4nger.'],
#  u'fr': u'y',
#  u'hw': u'doppelg\xe4nger',
#  u'idpvs': [u'dop\xb7pel\xb7gang\xb7er'],
#  u'infl': {u'1np1': u'doppelg\xe4ngers', u'1ns1': u'doppelg\xe4nger'},
#  u'label': [u'literary'],
#  u'pos': u'or',
#  u'sublist': [{u'def': u'1 : someone who looks like someone else  ',
#    u'es': [u'I saw your doppelg\xe4nger [=(more commonly) double] yesterday.']},
#   {u'def': u'2 literary : a ghost that looks like a living person ',
#    u'es': [u'In the story, the character is haunted by a doppelg\xe4nger.']}]}

# %%
dpdict.find({"id":"filepos18005907"})

# %%
comment = re.compile(r'/\*(.*?)\*/', re.DOTALL)
patt = '<img hspace="0" align="middle" losrc="Images\/image21955\.gif" src="Images\/image21956\.gif" hisrc="Images\/image21957\.gif"\/>'
pattern = patt + '(.*?)' + patt
print pattern
ipa = re.compile(pattern, re.DOTALL)
text1 = '/* this is a comment */'
text2 = '''/* this is a
        multiline comment */
        '''
text3 = '''<idx:entry scriptable="yes"><idx:orth value="vast"><idx:infl>  <idx:iform name="1.adj.pos.1" value="vast"/></idx:infl><idx:infl>  <idx:iform name="2.n.s.1" value="vast"/>  <idx:iform name="2.n.p.1" value="vasts"/></idx:infl></idx:orth><a id="filepos83514877" /><span><font size="3"><b><u>vast</u></span> <img hspace="0" align="middle" losrc="Images/image21955.gif" src="Images/image21956.gif" hisrc="Images/image21957.gif"/><img hspace="0" align="middle" losrc="Images/image21958.gif" src="Images/image21959.gif" hisrc="Images/image21960.gif"/><img hspace="0" align="middle" losrc="Images/image22003.gif" src="Images/image22004.gif" hisrc="Images/image22005.gif"/><img hspace="0" align="middle" losrc="Images/image21982.gif" src="Images/image21983.gif" hisrc="Images/image21984.gif"/><img hspace="0" align="middle" losrc="Images/image22012.gif" src="Images/image22013.gif" hisrc="Images/image22014.gif"/><img hspace="0" align="middle" losrc="Images/image22036.gif" src="Images/image22037.gif" hisrc="Images/image22038.gif"/><img hspace="0" align="middle" losrc="Images/image21976.gif" src="Images/image21977.gif" hisrc="Images/image21978.gif"/> <i>Brit</i> <img hspace="0" align="middle" losrc="Images/image21958.gif" src="Images/image21959.gif" hisrc="Images/image21960.gif"/><img hspace="0" align="middle" losrc="Images/image22003.gif" src="Images/image22004.gif" hisrc="Images/image22005.gif"/><img hspace="0" align="middle" losrc="Images/image21988.gif" src="Images/image21989.gif" hisrc="Images/image21990.gif"/><img hspace="0" align="middle" losrc="Images/image21991.gif" src="Images/image21992.gif" hisrc="Images/image21993.gif"/><img hspace="0" align="middle" losrc="Images/image22012.gif" src="Images/image22013.gif" hisrc="Images/image22014.gif"/><img hspace="0" align="middle" losrc="Images/image22036.gif" src="Images/image22037.gif" hisrc="Images/image22038.gif"/><img hspace="0" align="middle" losrc="Images/image21955.gif" src="Images/image21956.gif" hisrc="Images/image21957.gif"/> <i><font color="#999999">adj</font></i>, <b>vast積r</b>, <b>-est</b> [<i>more <img hspace="0" align="middle" losrc="Images/image22039.gif" src="Images/image22040.gif" hisrc="Images/image22041.gif"/>; most <img hspace="0" align="middle" losrc="Images/image22039.gif" src="Images/image22040.gif" hisrc="Images/image22041.gif"/></i>]<blockquote align="left"> <b>:</b> very great in size, amount, or extent <blockquote align="left"><font color="#002984">She has a <i>vast</i> amount of knowledge on this subject.</font></blockquote> <blockquote align="left"><font color="#002984"><i>vast</i> quantities of information</font></blockquote> <blockquote align="left"><font color="#002984">The policy is supported by the <i>vast</i> majority of citizens.</font></blockquote> <blockquote align="left"><font color="#002984">a <i>vast</i> expanse of land</font></blockquote></blockquote> <img hspace="0" vspace="0" align="middle" src="Images/image21970.gif"/><div align="left"><blockquote><span><font size="3"><b>vast穕y</span> <i><font color="#999999">adv</font></i> <blockquote><font color="#002984">His background is <i>vastly</i> different from mine.</font></blockquote> <blockquote><font color="#002984">They <i>vastly</i> increased spending.</font></blockquote></blockquote> </div>

<img hspace="0" vspace="0" align="middle" src="Images/image21970.gif"/><div align="left"><blockquote><span><font size="3"><b>vast穘ess</span> 

<img hspace="0" align="middle" losrc="Images/image21955.gif" src="Images/image21956.gif" hisrc="Images/image21957.gif"/>
<img hspace="0" align="middle" losrc="Images/image21958.gif" src="Images/image21959.gif" hisrc="Images/image21960.gif"/>
<img hspace="0" align="middle" losrc="Images/image22003.gif" src="Images/image22004.gif" hisrc="Images/image22005.gif"/>
<img hspace="0" align="middle" losrc="Images/image21982.gif" src="Images/image21983.gif" hisrc="Images/image21984.gif"/>
<img hspace="0" align="middle" losrc="Images/image22012.gif" src="Images/image22013.gif" hisrc="Images/image22014.gif"/>
<img hspace="0" align="middle" losrc="Images/image22036.gif" src="Images/image22037.gif" hisrc="Images/image22038.gif"/>
<img hspace="0" align="middle" losrc="Images/image21979.gif" src="Images/image21980.gif" hisrc="Images/image21981.gif"/>
<img hspace="0" align="middle" losrc="Images/image21973.gif" src="Images/image21974.gif" hisrc="Images/image21975.gif"/>
<img hspace="0" align="middle" losrc="Images/image22012.gif" src="Images/image22013.gif" hisrc="Images/image22014.gif"/>
<img hspace="0" align="middle" losrc="Images/image21976.gif" src="Images/image21977.gif" hisrc="Images/image21978.gif"/>
 <i>Brit</i> 
 <img hspace="0" align="middle" losrc="Images/image21958.gif" src="Images/image21959.gif" hisrc="Images/image21960.gif"/>
 <img hspace="0" align="middle" losrc="Images/image22003.gif" src="Images/image22004.gif" hisrc="Images/image22005.gif"/>
 <img hspace="0" align="middle" losrc="Images/image21988.gif" src="Images/image21989.gif" hisrc="Images/image21990.gif"/>
 <img hspace="0" align="middle" losrc="Images/image21991.gif" src="Images/image21992.gif" hisrc="Images/image21993.gif"/>
 <img hspace="0" align="middle" losrc="Images/image22012.gif" src="Images/image22013.gif" hisrc="Images/image22014.gif"/>
 <img hspace="0" align="middle" losrc="Images/image22036.gif" src="Images/image22037.gif" hisrc="Images/image22038.gif"/>
 <img hspace="0" align="middle" losrc="Images/image21979.gif" src="Images/image21980.gif" hisrc="Images/image21981.gif"/>
 <img hspace="0" align="middle" losrc="Images/image21973.gif" src="Images/image21974.gif" hisrc="Images/image21975.gif"/>
 <img hspace="0" align="middle" losrc="Images/image22012.gif" src="Images/image22013.gif" hisrc="Images/image22014.gif"/>
<img hspace="0" align="middle" losrc="Images/image21955.gif" src="Images/image21956.gif" hisrc="Images/image21957.gif"/> 


<i><font color="#999999">noun</font></i> [<i>noncount</i>] <blockquote><font color="#002984">the <i>vastness</i> of the desert/ocean</font></blockquote></blockquote></div></idx:entry><div><img hspace="0" vspace="0" align="middle" src="Images/image21971.gif"/></div><div><table width="100%" bgcolor="#7593CD"><tr><th widht="100%" height="2px"/></tr></table></div><div><img hspace="0" vspace="0" align="middle" src="Images/image21972.gif"/></div> 
 
 '''
#comment.findall(text1)
#comment.findall(text2)
for sounds in ipa.findall(text3):
    for sound in sounds.split('<i>Brit</i>'):
        print "---\n"
        soup = BeautifulSoup(sound)
        for symbol in soup.find_all('img'):
            print symbol['hisrc']
# Out:
# <img hspace="0" align="middle" losrc="Images\/image21955\.gif" src="Images\/image21956\.gif" hisrc="Images\/image21957\.gif"\/>(.*?)<img hspace="0" align="middle" losrc="Images\/image21955\.gif" src="Images\/image21956\.gif" hisrc="Images\/image21957\.gif"\/>
# ---
#
# Images/image21960.gif
# Images/image22005.gif
# Images/image21984.gif
# Images/image22014.gif
# Images/image22038.gif
# Images/image21978.gif
# ---
#
# Images/image21960.gif
# Images/image22005.gif
# Images/image21990.gif
# Images/image21993.gif
# Images/image22014.gif
# Images/image22038.gif
# ---
#
# Images/image21960.gif
# Images/image22005.gif
# Images/image21984.gif
# Images/image22014.gif
# Images/image22038.gif
# Images/image21981.gif
# Images/image21975.gif
# Images/image22014.gif
# Images/image21978.gif
# ---
#
# Images/image21960.gif
# Images/image22005.gif
# Images/image21990.gif
# Images/image21993.gif
# Images/image22014.gif
# Images/image22038.gif
# Images/image21981.gif
# Images/image21975.gif
# Images/image22014.gif

# %% [raw]
# Vowels
#
# @  æ ask bat glad
#
# a:   ɑ: cot bomb caught paw
#
# e    ɛ bet fed
#
# .    ə about banana collide
#
# i  i very any thirty
#
# i:   i: eat bead bee
#
# !    ɪ id bid pit
#
# u   ʊ foot should put
#
# u:  u: boot two coo
#
# ^   ʌ under putt bud
#
# ~   ɚ merge bird further
#
# ei   eɪ eight wade bay
#
# ai   aɪ ice bite tie
#
# au   aʊ out gown plow
#
# oi    oɪ oyster coil boy
#
# ou   oʊ oat own zone blow
#
# a~  ɑɚ car heart bizarre
#
# e~  eɚ bare fair wear
#
# i~   iɚ near deer mere pier
#
# o~   oɚ boar port door shore
#
# u~   uɚ boor tour insure
#
#
# Consonants
#
# b   b baby labor cab
#
# d   d day kid
#
# dZ   ʤ just badger fudge
#
# TH  ð then either bathe
#
# f   f foe tough buff
#
# g   g go dagger bag
#
# h   h hot ahead
#
# j   j yes vineyard
#
# k   k lacquer flock skin
#
# l   l law hollow
#
# l-   l̟ pedal battle final
#
# m   m mat hemp hammer rim
#
# n   n new tent tenor run
#
# n-   n̩ button satin kitten
#
# N   ŋ rung hang swinger
#
# p   p lapse top lip speed
#
# r   r rope arrive
#
# s   s sad mist kiss
#
# S   ʃ shoe mission slush
#
# t   t mat stick late
#
# (tʰ toe attack)
#
# (ɾ later catty riddle)
#
# tS   tʃ batch nature
#
# (tʃʰ choose chin achieve)
#
# th   θ thin ether bath
#
# v   v vat never cave
#
# w   w wet software
#
# z   z zoo easy buzz
#
# Z   ʒ vision azure beige
#
# Other Symbols
#
# '   ' penmanship
# ,  ˌ penmanship

# %%
import pymongo
from pymongo import MongoClient

#connect to MongoDB
client = MongoClient('localhost', 27017)
db = client.dpdb
dpdict = db.dpdict

# %%
words = dpdict.find({"hw":"incongruous"})
for word in words:
    print word.get("alles")
    print word.get("sublist")
# Out:
# [u'His outburst seemed incongruous to those who know him well.', u'The style of the porch is incongruous with [=does not match] the style of the house overall.', u'The modern sculpture seems incongruous [=out of place] among all the antiques.']
# [{u'def': u' : strange because of not agreeing with what is usual or expected   ', u'es': [u'His outburst seemed incongruous to those who know him well.', u'The style of the porch is incongruous with [=does not match] the style of the house overall.', u'The modern sculpture seems incongruous [=out of place] among all the antiques.']}, {u'idpv1': u'in\xb7con\xb7gru\xb7i\xb7ty noun, pl -ties [count, noncount]'}, {u'idpv2': u'in\xb7con\xb7gru\xb7ous\xb7ly adv'}]
